# %%
# %matplotlib inline
from monai.utils import first, set_determinism
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
)
from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob
import tarfile
import numpy as np
from torch.utils.data import Subset
import copy
set_determinism(seed=0)
np.random.seed(0)
import torch.nn.functional as F
import time
import pandas as pd

#print_config()

# %% [markdown]
# ## Read data

# %%
# read data
def get_spleen_dataset(data_dir):
    train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
    print(train_images)
    train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))
    data_dicts = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]
    train_files, val_files = data_dicts[:-9], data_dicts[-9:]
    
    train_transforms = Compose(
        [
            LoadImaged(keys=["image", "label"]),
            EnsureChannelFirstd(keys=["image", "label"]),
            ScaleIntensityRanged(
                keys=["image"],
                a_min=-57,
                a_max=164,
                b_min=0.0,
                b_max=1.0,
                clip=True,
            ),
            CropForegroundd(keys=["image", "label"], source_key="image"),
            Orientationd(keys=["image", "label"], axcodes="RAS"),
            Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
            RandCropByPosNegLabeld(
                keys=["image", "label"],
                label_key="label",
                spatial_size=(96, 96, 96),
                pos=1,
                neg=1,
                num_samples=4,
                image_key="image",
                image_threshold=0,
            ),
        ]
    )
    val_transforms = Compose(
        [
            LoadImaged(keys=["image", "label"]),
            EnsureChannelFirstd(keys=["image", "label"]),
            ScaleIntensityRanged(
                keys=["image"],
                a_min=-57,
                a_max=164,
                b_min=0.0,
                b_max=1.0,
                clip=True,
            ),
            CropForegroundd(keys=["image", "label"], source_key="image"),
            Orientationd(keys=["image", "label"], axcodes="RAS"),
            Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        ]
    )
    
    train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4)
    val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4)
    
    return train_ds, val_ds

# %%
# split the dataset into iid subsets
def split_dataset_iid(train_dataset, val_dataset, num_clients):
    #make the dataset evenly divisible by removing the last elements if needed
    train_dataset = train_dataset[:len(train_dataset) - len(train_dataset) % num_clients]
    val_dataset = val_dataset[:len(val_dataset) - len(val_dataset) % num_clients]
    
    #split the dataset into num_clients subsets randomly 
    train_indices = np.random.permutation(len(train_dataset))
    val_indices = np.random.permutation(len(val_dataset))
    train_client_splits = np.array_split(train_indices, num_clients)
    val_client_splits = np.array_split(val_indices, num_clients)
    
    #create a list of subsets
    train_client_datasets = [Subset(train_dataset, split) for split in train_client_splits]
    val_client_datasets = [Subset(val_dataset, split) for split in val_client_splits]
    
    return train_client_datasets, val_client_datasets

# %%
# split the dataset into non-iid subsets
def split_dataset_non_iid(train_dataset, val_dataset, num_clients):
    if len(train_dataset) % num_clients != 0 or len(val_dataset) % num_clients != 0:
         #split the dataset into num_clients subsets randomly 
        train_indices = np.random.permutation(len(train_dataset))
        val_indices = np.random.permutation(len(val_dataset))
        train_client_splits = np.array_split(train_indices, num_clients)
        val_client_splits = np.array_split(val_indices, num_clients)
        
        #create a list of subsets
        train_client_datasets = [Subset(train_dataset, split) for split in train_client_splits]
        val_client_datasets = [Subset(val_dataset, split) for split in val_client_splits]
        
        return train_client_datasets, val_client_datasets
    
    else: 
        while len(train_dataset) % num_clients == 0:
            train_dataset = train_dataset[:len(train_dataset) - 1]
        return split_dataset_non_iid(train_dataset, val_dataset, num_clients)

# %%
#set the data path
root_dir = os.path.dirname(os.path.dirname(os.path.abspath("federated_learning")))
data_dir = os.path.join(root_dir, "data/raw/Task09_Spleen/")
model_dir = os.path.join(root_dir, "models_gpu")

# %%
#load the entire dataset
train_ds, val_ds = get_spleen_dataset(data_dir)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=4)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=4)

#split the dataset into num_clients non IID subsets
num_clients = 4
train_client_datasets, val_client_datasets = split_dataset_non_iid(train_ds, val_ds, num_clients)

#check the number of samples in each client
for i, client_data in enumerate(val_client_datasets):
    print(f"Client {i+1} has {len(client_data)} samples.")
# Out:
# ['c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_10.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_12.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_13.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_14.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_16.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_17.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_18.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_19.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_2.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_20.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_21.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_22.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_24.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_25.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_26.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_27.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_28.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_29.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_3.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_31.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_32.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_33.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_38.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_40.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_41.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_44.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_45.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_46.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_47.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_49.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_52.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_53.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_56.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_59.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_6.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_60.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\fede ...
# Loading dataset: 100%|██████████| 32/32 [00:28<00:00,  1.12it/s]
# Loading dataset: 100%|██████████| 9/9 [00:06<00:00,  1.37it/s]
# Client 1 has 3 samples.
# Client 2 has 2 samples.
# Client 3 has 2 samples.
# Client 4 has 2 samples.

# %% [markdown]
# # FedAvg with knowledge distillation

# %%
class FedAvg:
    def __init__(self, model, loss_function, device, num_clients, client_fraction, local_epochs, batch_size, lr=1e-4,
                 teacher_model=None, alpha=0.5, temperature=2.0):
        """
        Args:
            teacher_model: Pretrained teacher model for knowledge distillation.
            alpha: Weighting factor for distillation loss.
            temperature: Temperature for softening logits in distillation.
        """
        self.global_model = model
        self.loss_function = loss_function
        self.device = device
        self.num_clients = num_clients
        self.client_fraction = client_fraction
        self.local_epochs = local_epochs
        self.batch_size = batch_size
        self.lr = lr
        self.teacher_model = teacher_model.to(device) if teacher_model else None
        self.alpha = alpha
        self.temperature = temperature
        self.clients = []

        self.round_loss_values = []
        self.dice_metric_values = []

    def set_clients(self, train_datasets, val_datasets):
        self.clients = [{"train": train, "val": val} for train, val in zip(train_datasets, val_datasets)]

        # Track communication costs
        self.communication_cost = 0  # For KD-based lightweight models
        self.communication_time = 0  # Total time spent in communication (in seconds)
        self.param_count = 0  # Total number of parameters exchanged

    def calculate_model_size(self, model_state_dict):
        """
        Calculate the size of the model state in bytes.
        """
        return sum(param.numel() * param.element_size() for param in model_state_dict.values())
    
    def calculate_parameter_count(self, model_state_dict):
        """
        Count the number of parameters in the model state.
        """
        return sum(param.numel() for param in model_state_dict.values())

    def distillation_loss(self, student_logits, teacher_logits):
        """
        Compute the distillation loss using KL divergence between softened logits.
        Args:
            student_logits: Logits from the student model.
            teacher_logits: Logits from the teacher model.
        """
        student_soft = F.log_softmax(student_logits / self.temperature, dim=1)
        teacher_soft = F.softmax(teacher_logits / self.temperature, dim=1)
        return F.kl_div(student_soft, teacher_soft, reduction="batchmean") * (self.temperature ** 2)
    
    def client_update(self, client_data):
        """
        Perform local training on a client with optional knowledge distillation.
        Args:
            client_data: A dictionary with 'train' and 'val' datasets for the client.
        Returns:
            Updated weights (state_dict) of the local model, and its size.
        """
        # Initialize a local model
        local_model = copy.deepcopy(self.global_model)
        local_model.train()
        local_model.to(self.device)
        local_train_start = time.time()

        # Freeze the teacher model if provided
        if self.teacher_model:
            self.teacher_model.eval()

        train_loader = DataLoader(client_data["train"], batch_size=self.batch_size, shuffle=True, num_workers=4)
        optimizer = torch.optim.Adam(local_model.parameters(), lr=self.lr)

        total_loss = 0
        num_batches = 0

        # Perform local training    
        for _ in range(self.local_epochs):
            for batch_data in train_loader:
                inputs, labels = (
                    batch_data["image"].to(self.device),
                    batch_data["label"].to(self.device),
                )
                optimizer.zero_grad()
                outputs = local_model(inputs)

                # Compute Dice loss
                dice_loss = self.loss_function(outputs, labels)

                if self.teacher_model:
                    with torch.no_grad():
                        teacher_outputs = self.teacher_model(inputs)

                    # Compute distillation loss
                    distill_loss = self.distillation_loss(outputs, teacher_outputs)
                    distill_loss = torch.sigmoid(distill_loss)

                    # Combine Dice loss and distillation loss
                    task_specific_loss = dice_loss.item()
                    loss = self.alpha * distill_loss + (1 - self.alpha) * dice_loss
                    
                else:
                    loss = dice_loss

                loss.backward()
                optimizer.step()
                
                if self.teacher_model:
                    total_loss += task_specific_loss
                else:
                    total_loss += loss.item()
                
                num_batches += 1

        local_train_end = time.time()

        # Calculate the average loss for this client
        loss_per_client = total_loss / num_batches if num_batches > 0 else 0

        # Calculate model size for communication cost
        model_size = self.calculate_model_size(local_model.state_dict())

        # Calculate number of parameters passed for communication cost
        num_params = self.calculate_parameter_count(local_model.state_dict())

        local_train_time = local_train_end - local_train_start

        return local_model.state_dict(), loss_per_client, model_size, num_params, local_train_time
    
    def aggregate_updates(self, client_updates, client_sizes):
        """
        Aggregate client updates to update the global model.
        Args:
            client_updates: List of state_dicts from clients.
            client_sizes: List of dataset sizes for each client.
        Returns:
            Aggregated weights for the global model.
        """
        # Initialize global weights
        global_weights = copy.deepcopy(self.global_model.state_dict())
        total_size = sum(client_sizes)

        # Perform weighted aggregation
        for key in global_weights.keys():
            global_weights[key] = sum(
                client_updates[i][key] * client_sizes[i] / total_size for i in range(len(client_updates))
            )

        return global_weights

    def evaluate_global_model(self, val_datasets, post_pred, post_label, dice_metric):
        """
        Evaluate the global model on all clients' validation datasets.
        Args:
            val_datasets: List of validation datasets for each client.
            post_pred: Post-processing function for predictions.
            post_label: Post-processing function for labels.
            dice_metric: Metric instance for Dice score.
        Returns:
            Average Dice score across all validation datasets.
        """
        self.global_model.eval()
        dice_scores = []

        for val_data in val_datasets:
            val_loader = DataLoader(val_data, batch_size=1, num_workers=4)
            with torch.no_grad():
                for batch_data in val_loader:
                    val_inputs, val_labels = (
                        batch_data["image"].to(self.device),
                        batch_data["label"].to(self.device),
                    )
                    roi_size = (160, 160, 160)
                    sw_batch_size = 4
                    val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, self.global_model)
                    val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                    val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                    dice_metric(y_pred=val_outputs, y=val_labels)

                # Aggregate Dice metric for this client
                dice_score = dice_metric.aggregate().item()
                dice_scores.append(dice_score)
                dice_metric.reset()

        return np.mean(dice_scores)

    def run(self, num_rounds, post_pred, post_label, dice_metric):
        """
        Run the FedAvg algorithm for the specified number of rounds.
        Args:
            num_rounds: Number of global training rounds.
            post_pred: Post-processing function for predictions.
            post_label: Post-processing function for labels.
            dice_metric: Metric instance for Dice score.
        """
        global_weights = self.global_model.state_dict()

        self.communication_time = 0  # Reset communication time
        self.param_count = 0  # Reset parameter count

        for round_num in range(num_rounds):
            print(f"--- Round {round_num + 1} ---")

            # Randomly select clients
            num_selected_clients = max(int(self.client_fraction * self.num_clients), 1)
            selected_clients = np.random.choice(self.num_clients, num_selected_clients, replace=False)

            client_updates = []
            client_sizes = []
            total_loss = 0

            round_start_time = time.time()
            
            # Each selected client performs local training
            for client_id in selected_clients:
                client_data = self.clients[client_id]
                client_size = len(client_data["train"])
                client_sizes.append(client_size)

                updated_weights, loss_per_client, model_size, num_params, local_train_time = self.client_update(client_data)
                client_updates.append(updated_weights)
                total_loss += loss_per_client

                # Track communication cost
                self.communication_time -= local_train_time
                # print(local_train_time, self.communication_time)
                self.communication_cost += model_size
                self.param_count += num_params

            round_end_time = time.time()

            self.communication_time += (round_end_time - round_start_time)
            # print(round_end_time - round_start_time, self.communication_time)

            # Aggregate updates to update global model weights
            global_weights = self.aggregate_updates(client_updates, client_sizes)
            self.global_model.load_state_dict(global_weights)

            # Evaluate the global model on all validation datasets
            avg_dice_score = self.evaluate_global_model(
                [client["val"] for client in self.clients],
                post_pred,
                post_label,
                dice_metric,
            )
            print(f"Average Dice Score after Round {round_num + 1}: {avg_dice_score:.4f}")

            self.dice_metric_values.append(avg_dice_score)
            avg_loss_per_round = total_loss / len(selected_clients) if len(selected_clients) > 0 else 0
            self.round_loss_values.append(avg_loss_per_round)

        # Print communication costs
        print(f"Total communication cost: {self.communication_cost / 1e6:.2f} MB")
        print(f"Total communication time: {self.communication_time:.2f} seconds")
        print(f"Total parameters exchanged: {self.param_count}")

# %% [markdown]
# # Model training

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
## KD non iid

# initialize the models
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

student_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(8, 16, 32, 64),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

teacher_state_dict = torch.load(os.path.join(model_dir, "fedavg_r200_niid.pth"))

teacher_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
teacher_model.load_state_dict(teacher_state_dict['global_model_state'])

num_clients = 4  # Total number of clients
client_fraction = 0.5  # Fraction of clients selected per round
local_epochs = 2  # Number of epochs each client trains locally
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])

fedavg = FedAvg(
    model=student_model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=0.5,
    local_epochs=2,
    batch_size=2,
    lr=1e-4,
    teacher_model=teacher_model,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedavg.set_clients(train_client_datasets, val_client_datasets)

fedavg.run(
    num_rounds=200,           
    post_pred=post_pred,     
    post_label=post_label,   
    dice_metric=dice_metric  
)

torch.save({
    'round_losses': fedavg.round_loss_values,
    'dice_scores': fedavg.dice_metric_values,
    'model size': fedavg.communication_cost, ##bandwidth or data transfer
    'communication time': fedavg.communication_time, ## training and convergence time
    'parameter count': fedavg.param_count,
    'global_model_state': fedavg.global_model.state_dict()
}, 'fedavg_kd_r200_niid.pth')

#alt: cosine similarity or comparing mse between teacher and student or KL efficiency or comparing loss between teacher and student
# Out:
# c:\Users\edmund\anaconda3\envs\pytorch\lib\site-packages\monai\networks\nets\unet.py:130: UserWarning: `len(strides) > len(channels) - 1`, the last 1 values of strides will not be used.
#   warnings.warn(f"`len(strides) > len(channels) - 1`, the last {delta} values of strides will not be used.")
# C:\Users\edmund\AppData\Local\Temp\ipykernel_7924\2799337371.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher_state_dict = torch.load(os.path.join(model_dir, "fedavg_r200_niid.pth"))
# --- Round 1 ---
# Average Dice Score after Round 1: 0.0132
# --- Round 2 ---
# Average Dice Score after Round 2: 0.0192
# --- Round 3 ---
# Average Dice Score after Round 3: 0.0288
# --- Round 4 ---
# Average Dice Score after Round 4: 0.0348
# --- Round 5 ---
# Average Dice Score after Round 5: 0.0382
# --- Round 6 ---
# Average Dice Score after Round 6: 0.0435
# --- Round 7 ---
# Average Dice Score after Round 7: 0.0515
# --- Round 8 ---
# Average Dice Score after Round 8: 0.0511
# --- Round 9 ---
# Average Dice Score after Round 9: 0.0521
# --- Round 10 ---
# Average Dice Score after Round 10: 0.0589
# --- Round 11 ---
# Average Dice Score after Round 11: 0.0602
# --- Round 12 ---
# Average Dice Score after Round 12: 0.0735
# --- Round 13 ---
# Average Dice Score after Round 13: 0.0630
# --- Round 14 ---
# Average Dice Score after Round 14: 0.0747
# --- Round 15 ---
# Average Dice Score after Round 15: 0.0792
# --- Round 16 ---
# Average Dice Score after Round 16: 0.1028
# --- Round 17 ---
# Average Dice Score after Round 17: 0.0751
# --- Round 18 ---
# Average Dice Score after Round 18: 0.0851
# --- Round 19 ---
# Average Dice Score after Round 19: 0.1226
# --- Round 20 ---
# Average Dice Score after Round 20: 0.0921
# --- Round 21 ---
# Average Dice Score after Round 21: 0.0828
# --- Round 22 ---
# Average Dice Score after Round 22: 0.0992
# --- Round 23 ---
# Average Dice Score after Round 23: 0.1245
# --- Round 24 ---
# Average Dice Score after Round 24: 0.0975
# --- Round 25 ---
# Average Dice Score after Round 25: 0.1825
# --- Round 26 ---
# Average Dice Score after Round 26: 0.1114
# --- Round 27 ---
# Average Dice Score after Round 27: 0.1155
# --- Round 28 ---
# Average Dice Score after Round 28: 0.1802
# --- Round 29 ---
# Average Dice Score after Round 29: 0.1475
# --- Round 30 ---
# Average Dice Score after Round 30: 0.1004
# --- Round 31 ---
# Average Dice Score after Round 31: 0.0954
# --- Round 32 ---
# Average Dice Score after Round 32: 0.1168
# --- Round 33 ---
# Average Dice Score after Round 33: 0.0939
# --- Round 34 ---
# Average Dice Score after Round 34: 0.1003
# --- Round 35 ---
# Average Dice Score after Round 35: 0.0907
# --- Round 36 ---
# Average Dice Score after Round 36: 0.1038
# --- Round 37 ---
# Average Dice Score after Round 37: 0.1025
# --- Round 38 ---
# Average Dice Score after Round 38: 0.0892
# --- Round 39 ---
# Average Dice Score after Round 39: 0.1283
# --- Round 40 ---
# Average Dice Score after Round 40: 0.1200
# --- Round 41 ---
# Average Dice Score after Round 41: 0.1301
# --- Round 42 ---
# Average Dice Score after Round 42: 0.1492
# --- Round 43 ---
# Average Dice Score after Round 43: 0.1034
# --- Round 44 ---
# Average Dice Score after Round 44: 0.1047
# --- Round 45 ---
# Average Dice Score after Round 45: 0.1615
# --- Round 46 ---
# Average Dice Score after Round 46: 0.2236
# --- Round 47 ---
# Average Dice Score after Round 47: 0.1584
# --- Round 48 ---
# Average Dice Score after Round 48: 0.1410
# --- Round 49 ---
# Average Dice Score after Round 49: 0.2407
# --- Round 50 ---
# Average Dice Score after Round 50: 0.1907
# --- Round 51 ---
# Average Dice Score after Round 51: 0.1931
# --- Round 52 ---
# Average Dice Score after Round 52: 0.1790
# --- Round 53 ---
# Average Dice Score after Round 53: 0.1137
# --- Round 54 ---
# Average Dice Score after Round 54: 0.3795
# --- Round 55 ---
# Average Dice Score after Round 55: 0.2850
# --- Round 56 ---
# Average Dice Score after Round 56: 0.4624
# --- Round 57 ---
# Average Dice Score after Round 57: 0.1680
# --- Round 58 ---
# Average Dice Score after Round 58: 0.2064
# --- Round 59 ---
# Average Dice Score after Round 59: 0.1110
# --- Round 60 ---
# Average Dice Score after Round 60: 0.1482
# --- Round 61 ---
# Average Dice Score after Round 61: 0.3036
# --- Round 62 ---
# Average Dice Score after Round 62: 0.2380
# --- Round 63 ---
# Average Dice Score after Round 63: 0.3550
# --- Round 64 ---
# Average Dice Score after Round 64: 0.1749
# --- Round 65 ---
# Average Dice Score after Round 65: 0.2339
# --- Round 66 ---
# Average Dice Score after Round 66: 0.1493
# --- Round 67 ---
# Average Dice Score after Round 67: 0.1728
# --- Round 68 ---
# Average Dice Score after Round 68: 0.2709
# --- Round 69 ---
# Average Dice Score after Round 69: 0.1944
# --- Round 70 ---
# Average Dice Score after Round 70: 0.1984
# --- Round 71 ---
# Average Dice Score after Round 71: 0.1588
# --- Round 72 ---
# Average Dice Score after Round 72: 0.1356
# --- Round 73 ---
# Average Dice Score after Round 73: 0.1298
# --- Round 74 ---
# Average Dice Score after Round 74: 0.1991
# --- Round 75 ---
# Average Dice Score after Round 75: 0.2590
# --- Round 76 ---
# Average Dice Score after Round 76: 0.1606
# --- Round 77 ---
# Average Dice Score after Round 77: 0.2008
# --- Round 78 ---
# Average Dice Score after Round 78: 0.1685
# --- Round 79 ---
# Average Dice Score after Round 79: 0.1228
# --- Round 80 ---
# Average Dice Score after Round 80: 0.4160
# --- Round 81 ---
# Average Dice Score after Round 81: 0.1809
# --- Round 82 ---
# Average Dice Score after Round 82: 0.2694
# --- Round 83 ---
# Average Dice Score after Round 83: 0.3545
# --- Round 84 ---
# Average Dice Score after Round 84: 0.4335
# --- Round 85 ---
# Average Dice Score after Round 85: 0.1526
# --- Round 86 ---
# Average Dice Score after Round 86: 0.2508
# --- Round 87 ---
# Average Dice Score after Round 87: 0.1848
# --- Round 88 ---
# Average Dice Score after Round 88: 0.2183
# --- Round 89 ---
# Average Dice Score after Round 89: 0.2582
# --- Round 90 ---
# Average Dice Score after Round 90: 0.0994
# --- Round 91 ---
# Average Dice Score after Round 91: 0.1369
# --- Round 92 ---
# Average Dice Score after Round 92: 0.1929
# --- Round 93 ---
# Average Dice Score after Round 93: 0.4381
# --- Round 94 ---
# Average Dice Score after Round 94: 0.1593
# --- Round 95 ---
# Average Dice Score after Round 95: 0.1548
# --- Round 96 ---
# Average Dice Score after Round 96: 0.2289
# --- Round 97 ---
# Average Dice Score after Round 97: 0.3170
# --- Round 98 ---
# Average Dice Score after Round 98: 0.4702
# --- Round 99 ---
# Average Dice Score after Round 99: 0.1682
# --- Round 100 ---
# Average Dice Score after Round 100: 0.2030
# --- Round 101 ---
# Average Dice Score after Round 101: 0.2960
# --- Round 102 ---
# Average Dice Score after Round 102: 0.3273
# --- Round 103 ---
# Average Dice Score after Round 103: 0.4356
# --- Round 104 ---
# Average Dice Score after Round 104: 0.4208
# --- Round 105 ---
# Average Dice Score after Round 105: 0.2453
# --- Round 106 ---
# Average Dice Score after Round 106: 0.2452
# --- Round 107 ---
# Average Dice Score after Round 107: 0.2282
# --- Round 108 ---
# Average Dice Score after Round 108: 0.3159
# --- Round 109 ---
# Average Dice Score after Round 109: 0.2603
# --- Round 110 ---
# Average Dice Score after Round 110: 0.1740
# --- Round 111 ---
# Average Dice Score after Round 111: 0.3115
# --- Round 112 ---
# Average Dice Score after Round 112: 0.4211
# --- Round 113 ---
# Average Dice Score after Round 113: 0.4982
# --- Round 114 ---
# Average Dice Score after Round 114: 0.3371
# --- Round 115 ---
# Average Dice Score after Round 115: 0.3790
# --- Round 116 ---
# Average Dice Score after Round 116: 0.5666
# --- Round 117 ---
# Average Dice Score after Round 117: 0.4530
# --- Round 118 ---
# Average Dice Score after Round 118: 0.3765
# --- Round 119 ---
# Average Dice Score after Round 119: 0.4509
# --- Round 120 ---
# Average Dice Score after Round 120: 0.2594
# --- Round 121 ---
# Average Dice Score after Round 121: 0.4686
# --- Round 122 ---
# Average Dice Score after Round 122: 0.6196
# --- Round 123 ---
# Average Dice Score after Round 123: 0.7156
# --- Round 124 ---
# Average Dice Score after Round 124: 0.7103
# --- Round 125 ---
# Average Dice Score after Round 125: 0.3606
# --- Round 126 ---
# Average Dice Score after Round 126: 0.4140
# --- Round 127 ---
# Average Dice Score after Round 127: 0.7243
# --- Round 128 ---
# Average Dice Score after Round 128: 0.4444
# --- Round 129 ---
# Average Dice Score after Round 129: 0.6665
# --- Round 130 ---
# Average Dice Score after Round 130: 0.5694
# --- Round 131 ---
# Average Dice Score after Round 131: 0.3905
# --- Round 132 ---
# Average Dice Score after Round 132: 0.2621
# --- Round 133 ---
# Average Dice Score after Round 133: 0.4197
# --- Round 134 ---
# Average Dice Score after Round 134: 0.5944
# --- Round 135 ---
# Average Dice Score after Round 135: 0.5212
# --- Round 136 ---
# Average Dice Score after Round 136: 0.6445
# --- Round 137 ---
# Average Dice Score after Round 137: 0.4233
# --- Round 138 ---
# Average Dice Score after Round 138: 0.4767
# --- Round 139 ---
# Average Dice Score after Round 139: 0.5302
# --- Round 140 ---
# Average Dice Score after Round 140: 0.5273
# --- Round 141 ---
# Average Dice Score after Round 141: 0.5924
# --- Round 142 ---
# Average Dice Score after Round 142: 0.5440
# --- Round 143 ---
# Average Dice Score after Round 143: 0.3683
# --- Round 144 ---
# Average Dice Score after Round 144: 0.8027
# --- Round 145 ---
# Average Dice Score after Round 145: 0.5981
# --- Round 146 ---
# Average Dice Score after Round 146: 0.7876
# --- Round 147 ---
# Average Dice Score after Round 147: 0.7633
# --- Round 148 ---
# Average Dice Score after Round 148: 0.8126
# --- Round 149 ---
# Average Dice Score after Round 149: 0.8397
# --- Round 150 ---
# Average Dice Score after Round 150: 0.8748
# --- Round 151 ---
# Average Dice Score after Round 151: 0.6374
# --- Round 152 ---
# Average Dice Score after Round 152: 0.7297
# --- Round 153 ---
# Average Dice Score after Round 153: 0.5069
# --- Round 154 ---
# Average Dice Score after Round 154: 0.8255
# --- Round 155 ---
# Average Dice Score after Round 155: 0.7484
# --- Round 156 ---
# Average Dice Score after Round 156: 0.7649
# --- Round 157 ---
# Average Dice Score after Round 157: 0.3619
# --- Round 158 ---
# Average Dice Score after Round 158: 0.6560
# --- Round 159 ---
# Average Dice Score after Round 159: 0.6321
# --- Round 160 ---
# Average Dice Score after Round 160: 0.7344
# --- Round 161 ---
# Average Dice Score after Round 161: 0.7559
# --- Round 162 ---
# Average Dice Score after Round 162: 0.7077
# --- Round 163 ---
# Average Dice Score after Round 163: 0.6727
# --- Round 164 ---
# Average Dice Score after Round 164: 0.8072
# --- Round 165 ---
# Average Dice Score after Round 165: 0.8458
# --- Round 166 ---
# Average Dice Score after Round 166: 0.8492
# --- Round 167 ---
# Average Dice Score after Round 167: 0.6748
# --- Round 168 ---
# Average Dice Score after Round 168: 0.8572
# --- Round 169 ---
# Average Dice Score after Round 169: 0.6371
# --- Round 170 ---
# Average Dice Score after Round 170: 0.7943
# --- Round 171 ---
# Average Dice Score after Round 171: 0.7018
# --- Round 172 ---
# Average Dice Score after Round 172: 0.8141
# --- Round 173 ---
# Average Dice Score after Round 173: 0.8050
# --- Round 174 ---
# Average Dice Score after Round 174: 0.7085
# --- Round 175 ---
# Average Dice Score after Round 175: 0.8380
# --- Round 176 ---
# Average Dice Score after Round 176: 0.8150
# --- Round 177 ---
# Average Dice Score after Round 177: 0.5742
# --- Round 178 ---
# Average Dice Score after Round 178: 0.7168
# --- Round 179 ---
# Average Dice Score after Round 179: 0.7731
# --- Round 180 ---
# Average Dice Score after Round 180: 0.7134
# --- Round 181 ---
# Average Dice Score after Round 181: 0.8477
# --- Round 182 ---
# Average Dice Score after Round 182: 0.7989
# --- Round 183 ---
# Average Dice Score after Round 183: 0.7489
# --- Round 184 ---
# Average Dice Score after Round 184: 0.8298
# --- Round 185 ---
# Average Dice Score after Round 185: 0.7820
# --- Round 186 ---
# Average Dice Score after Round 186: 0.8333
# --- Round 187 ---
# Average Dice Score after Round 187: 0.8524
# --- Round 188 ---
# Average Dice Score after Round 188: 0.7766
# --- Round 189 ---
# Average Dice Score after Round 189: 0.8096
# --- Round 190 ---
# Average Dice Score after Round 190: 0.8736
# --- Round 191 ---
# Average Dice Score after Round 191: 0.7717
# --- Round 192 ---
# Average Dice Score after Round 192: 0.5144
# --- Round 193 ---
# Average Dice Score after Round 193: 0.8738
# --- Round 194 ---
# Average Dice Score after Round 194: 0.6244
# --- Round 195 ---
# Average Dice Score after Round 195: 0.8235
# --- Round 196 ---
# Average Dice Score after Round 196: 0.7666
# --- Round 197 ---
# Average Dice Score after Round 197: 0.7260
# --- Round 198 ---
# Average Dice Score after Round 198: 0.8293
# --- Round 199 ---
# Average Dice Score after Round 199: 0.8556
# --- Round 200 ---
# Average Dice Score after Round 200: 0.7232
# Total communication cost: 478.12 MB
# Total communication time: 11.74 seconds
# Total parameters exchanged: 119524000

# %%
## No KD non iid

fedavg_nkd = FedAvg(
    model=model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=0.5,
    local_epochs=2,
    batch_size=2,
    lr=1e-4,
    teacher_model=None,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedavg_nkd.set_clients(train_client_datasets, val_client_datasets)

fedavg_nkd.run(
    num_rounds=200,           
    post_pred=post_pred,     
    post_label=post_label,   
    dice_metric=dice_metric  
)

torch.save({
    'round_losses': fedavg_nkd.round_loss_values,
    'dice_scores': fedavg_nkd.dice_metric_values,
    'model size': fedavg_nkd.communication_cost,
    'communication time': fedavg_nkd.communication_time,
    'parameter count': fedavg_nkd.param_count,
    'global_model_state': fedavg_nkd.global_model.state_dict()
}, 'fedavg_nkd_r200_niid.pth')
# Out:
# --- Round 1 ---
# Average Dice Score after Round 1: 0.0144
# --- Round 2 ---
# Average Dice Score after Round 2: 0.0163
# --- Round 3 ---
# Average Dice Score after Round 3: 0.0246
# --- Round 4 ---
# Average Dice Score after Round 4: 0.0328
# --- Round 5 ---
# Average Dice Score after Round 5: 0.0402
# --- Round 6 ---
# Average Dice Score after Round 6: 0.0437
# --- Round 7 ---
# Average Dice Score after Round 7: 0.0446
# --- Round 8 ---
# Average Dice Score after Round 8: 0.0463
# --- Round 9 ---
# Average Dice Score after Round 9: 0.0483
# --- Round 10 ---
# Average Dice Score after Round 10: 0.0472
# --- Round 11 ---
# Average Dice Score after Round 11: 0.0476
# --- Round 12 ---
# Average Dice Score after Round 12: 0.0521
# --- Round 13 ---
# Average Dice Score after Round 13: 0.0539
# --- Round 14 ---
# Average Dice Score after Round 14: 0.0591
# --- Round 15 ---
# Average Dice Score after Round 15: 0.0596
# --- Round 16 ---
# Average Dice Score after Round 16: 0.0683
# --- Round 17 ---
# Average Dice Score after Round 17: 0.0564
# --- Round 18 ---
# Average Dice Score after Round 18: 0.0688
# --- Round 19 ---
# Average Dice Score after Round 19: 0.0717
# --- Round 20 ---
# Average Dice Score after Round 20: 0.0673
# --- Round 21 ---
# Average Dice Score after Round 21: 0.0701
# --- Round 22 ---
# Average Dice Score after Round 22: 0.0710
# --- Round 23 ---
# Average Dice Score after Round 23: 0.0777
# --- Round 24 ---
# Average Dice Score after Round 24: 0.0711
# --- Round 25 ---
# Average Dice Score after Round 25: 0.0610
# --- Round 26 ---
# Average Dice Score after Round 26: 0.0668
# --- Round 27 ---
# Average Dice Score after Round 27: 0.0553
# --- Round 28 ---
# Average Dice Score after Round 28: 0.0648
# --- Round 29 ---
# Average Dice Score after Round 29: 0.0564
# --- Round 30 ---
# Average Dice Score after Round 30: 0.0703
# --- Round 31 ---
# Average Dice Score after Round 31: 0.0716
# --- Round 32 ---
# Average Dice Score after Round 32: 0.0618
# --- Round 33 ---
# Average Dice Score after Round 33: 0.0589
# --- Round 34 ---
# Average Dice Score after Round 34: 0.0609
# --- Round 35 ---
# Average Dice Score after Round 35: 0.0486
# --- Round 36 ---
# Average Dice Score after Round 36: 0.0697
# --- Round 37 ---
# Average Dice Score after Round 37: 0.0560
# --- Round 38 ---
# Average Dice Score after Round 38: 0.0544
# --- Round 39 ---
# Average Dice Score after Round 39: 0.0486
# --- Round 40 ---
# Average Dice Score after Round 40: 0.0471
# --- Round 41 ---
# Average Dice Score after Round 41: 0.0608
# --- Round 42 ---
# Average Dice Score after Round 42: 0.0426
# --- Round 43 ---
# Average Dice Score after Round 43: 0.0558
# --- Round 44 ---
# Average Dice Score after Round 44: 0.0568
# --- Round 45 ---
# Average Dice Score after Round 45: 0.0642
# --- Round 46 ---
# Average Dice Score after Round 46: 0.0543
# --- Round 47 ---
# Average Dice Score after Round 47: 0.0358
# --- Round 48 ---
# Average Dice Score after Round 48: 0.0530
# --- Round 49 ---
# Average Dice Score after Round 49: 0.0455
# --- Round 50 ---
# Average Dice Score after Round 50: 0.0444
# --- Round 51 ---
# Average Dice Score after Round 51: 0.0340
# --- Round 52 ---
# Average Dice Score after Round 52: 0.0391
# --- Round 53 ---
# Average Dice Score after Round 53: 0.0408
# --- Round 54 ---
# Average Dice Score after Round 54: 0.0333
# --- Round 55 ---
# Average Dice Score after Round 55: 0.0381
# --- Round 56 ---
# Average Dice Score after Round 56: 0.0334
# --- Round 57 ---
# Average Dice Score after Round 57: 0.0296
# --- Round 58 ---
# Average Dice Score after Round 58: 0.0362
# --- Round 59 ---
# Average Dice Score after Round 59: 0.0307
# --- Round 60 ---
# Average Dice Score after Round 60: 0.0384
# --- Round 61 ---
# Average Dice Score after Round 61: 0.0305
# --- Round 62 ---
# Average Dice Score after Round 62: 0.0348
# --- Round 63 ---
# Average Dice Score after Round 63: 0.0265
# --- Round 64 ---
# Average Dice Score after Round 64: 0.0256
# --- Round 65 ---
# Average Dice Score after Round 65: 0.0259
# --- Round 66 ---
# Average Dice Score after Round 66: 0.0311
# --- Round 67 ---
# Average Dice Score after Round 67: 0.0277
# --- Round 68 ---
# Average Dice Score after Round 68: 0.0370
# --- Round 69 ---
# Average Dice Score after Round 69: 0.0293
# --- Round 70 ---
# Average Dice Score after Round 70: 0.0361
# --- Round 71 ---
# Average Dice Score after Round 71: 0.0271
# --- Round 72 ---
# Average Dice Score after Round 72: 0.0298
# --- Round 73 ---
# Average Dice Score after Round 73: 0.0244
# --- Round 74 ---
# Average Dice Score after Round 74: 0.0235
# --- Round 75 ---
# Average Dice Score after Round 75: 0.0376
# --- Round 76 ---
# Average Dice Score after Round 76: 0.0356
# --- Round 77 ---
# Average Dice Score after Round 77: 0.0298
# --- Round 78 ---
# Average Dice Score after Round 78: 0.0286
# --- Round 79 ---
# Average Dice Score after Round 79: 0.0292
# --- Round 80 ---
# Average Dice Score after Round 80: 0.0303
# --- Round 81 ---
# Average Dice Score after Round 81: 0.0320
# --- Round 82 ---
# Average Dice Score after Round 82: 0.0433
# --- Round 83 ---
# Average Dice Score after Round 83: 0.0297
# --- Round 84 ---
# Average Dice Score after Round 84: 0.0359
# --- Round 85 ---
# Average Dice Score after Round 85: 0.0419
# --- Round 86 ---
# Average Dice Score after Round 86: 0.0370
# --- Round 87 ---
# Average Dice Score after Round 87: 0.0479
# --- Round 88 ---
# Average Dice Score after Round 88: 0.0313
# --- Round 89 ---
# Average Dice Score after Round 89: 0.0302
# --- Round 90 ---
# Average Dice Score after Round 90: 0.0309
# --- Round 91 ---
# Average Dice Score after Round 91: 0.0337
# --- Round 92 ---
# Average Dice Score after Round 92: 0.0320
# --- Round 93 ---
# Average Dice Score after Round 93: 0.0335
# --- Round 94 ---
# Average Dice Score after Round 94: 0.0400
# --- Round 95 ---
# Average Dice Score after Round 95: 0.0342
# --- Round 96 ---
# Average Dice Score after Round 96: 0.0349
# --- Round 97 ---
# Average Dice Score after Round 97: 0.0508
# --- Round 98 ---
# Average Dice Score after Round 98: 0.0319
# --- Round 99 ---
# Average Dice Score after Round 99: 0.0410
# --- Round 100 ---
# Average Dice Score after Round 100: 0.0352
# --- Round 101 ---
# Average Dice Score after Round 101: 0.0330
# --- Round 102 ---
# Average Dice Score after Round 102: 0.0391
# --- Round 103 ---
# Average Dice Score after Round 103: 0.0476
# --- Round 104 ---
# Average Dice Score after Round 104: 0.0683
# --- Round 105 ---
# Average Dice Score after Round 105: 0.0329
# --- Round 106 ---
# Average Dice Score after Round 106: 0.0358
# --- Round 107 ---
# Average Dice Score after Round 107: 0.0397
# --- Round 108 ---
# Average Dice Score after Round 108: 0.0382
# --- Round 109 ---
# Average Dice Score after Round 109: 0.0335
# --- Round 110 ---
# Average Dice Score after Round 110: 0.0322
# --- Round 111 ---
# Average Dice Score after Round 111: 0.0375
# --- Round 112 ---
# Average Dice Score after Round 112: 0.0716
# --- Round 113 ---
# Average Dice Score after Round 113: 0.0541
# --- Round 114 ---
# Average Dice Score after Round 114: 0.0439
# --- Round 115 ---
# Average Dice Score after Round 115: 0.0499
# --- Round 116 ---
# Average Dice Score after Round 116: 0.0445
# --- Round 117 ---
# Average Dice Score after Round 117: 0.0456
# --- Round 118 ---
# Average Dice Score after Round 118: 0.0497
# --- Round 119 ---
# Average Dice Score after Round 119: 0.0307
# --- Round 120 ---
# Average Dice Score after Round 120: 0.0395
# --- Round 121 ---
# Average Dice Score after Round 121: 0.0356
# --- Round 122 ---
# Average Dice Score after Round 122: 0.0396
# --- Round 123 ---
# Average Dice Score after Round 123: 0.0424
# --- Round 124 ---
# Average Dice Score after Round 124: 0.0343
# --- Round 125 ---
# Average Dice Score after Round 125: 0.0350
# --- Round 126 ---
# Average Dice Score after Round 126: 0.0323
# --- Round 127 ---
# Average Dice Score after Round 127: 0.0381
# --- Round 128 ---
# Average Dice Score after Round 128: 0.0390
# --- Round 129 ---
# Average Dice Score after Round 129: 0.0483
# --- Round 130 ---
# Average Dice Score after Round 130: 0.0323
# --- Round 131 ---
# Average Dice Score after Round 131: 0.0402
# --- Round 132 ---
# Average Dice Score after Round 132: 0.0370
# --- Round 133 ---
# Average Dice Score after Round 133: 0.0387
# --- Round 134 ---
# Average Dice Score after Round 134: 0.0403
# --- Round 135 ---
# Average Dice Score after Round 135: 0.0485
# --- Round 136 ---
# Average Dice Score after Round 136: 0.0339
# --- Round 137 ---
# Average Dice Score after Round 137: 0.0400
# --- Round 138 ---
# Average Dice Score after Round 138: 0.0379
# --- Round 139 ---
# Average Dice Score after Round 139: 0.0376
# --- Round 140 ---
# Average Dice Score after Round 140: 0.0524
# --- Round 141 ---
# Average Dice Score after Round 141: 0.0457
# --- Round 142 ---
# Average Dice Score after Round 142: 0.0408
# --- Round 143 ---
# Average Dice Score after Round 143: 0.0419
# --- Round 144 ---
# Average Dice Score after Round 144: 0.0408
# --- Round 145 ---
# Average Dice Score after Round 145: 0.0527
# --- Round 146 ---
# Average Dice Score after Round 146: 0.0424
# --- Round 147 ---
# Average Dice Score after Round 147: 0.0377
# --- Round 148 ---
# Average Dice Score after Round 148: 0.0414
# --- Round 149 ---
# Average Dice Score after Round 149: 0.0424
# --- Round 150 ---
# Average Dice Score after Round 150: 0.0420
# --- Round 151 ---
# Average Dice Score after Round 151: 0.0384
# --- Round 152 ---
# Average Dice Score after Round 152: 0.0477
# --- Round 153 ---
# Average Dice Score after Round 153: 0.0824
# --- Round 154 ---
# Average Dice Score after Round 154: 0.0719
# --- Round 155 ---
# Average Dice Score after Round 155: 0.0675
# --- Round 156 ---
# Average Dice Score after Round 156: 0.0530
# --- Round 157 ---
# Average Dice Score after Round 157: 0.0575
# --- Round 158 ---
# Average Dice Score after Round 158: 0.0389
# --- Round 159 ---
# Average Dice Score after Round 159: 0.0464
# --- Round 160 ---
# Average Dice Score after Round 160: 0.0450
# --- Round 161 ---
# Average Dice Score after Round 161: 0.0638
# --- Round 162 ---
# Average Dice Score after Round 162: 0.0422
# --- Round 163 ---
# Average Dice Score after Round 163: 0.0592
# --- Round 164 ---
# Average Dice Score after Round 164: 0.0636
# --- Round 165 ---
# Average Dice Score after Round 165: 0.0757
# --- Round 166 ---
# Average Dice Score after Round 166: 0.0489
# --- Round 167 ---
# Average Dice Score after Round 167: 0.0448
# --- Round 168 ---
# Average Dice Score after Round 168: 0.0495
# --- Round 169 ---
# Average Dice Score after Round 169: 0.0351
# --- Round 170 ---
# Average Dice Score after Round 170: 0.0393
# --- Round 171 ---
# Average Dice Score after Round 171: 0.0399
# --- Round 172 ---
# Average Dice Score after Round 172: 0.0598
# --- Round 173 ---
# Average Dice Score after Round 173: 0.0472
# --- Round 174 ---
# Average Dice Score after Round 174: 0.0496
# --- Round 175 ---
# Average Dice Score after Round 175: 0.0451
# --- Round 176 ---
# Average Dice Score after Round 176: 0.0667
# --- Round 177 ---
# Average Dice Score after Round 177: 0.0517
# --- Round 178 ---
# Average Dice Score after Round 178: 0.0825
# --- Round 179 ---
# Average Dice Score after Round 179: 0.0740
# --- Round 180 ---
# Average Dice Score after Round 180: 0.0474
# --- Round 181 ---
# Average Dice Score after Round 181: 0.0477
# --- Round 182 ---
# Average Dice Score after Round 182: 0.0503
# --- Round 183 ---
# Average Dice Score after Round 183: 0.0715
# --- Round 184 ---
# Average Dice Score after Round 184: 0.2068
# --- Round 185 ---
# Average Dice Score after Round 185: 0.0365
# --- Round 186 ---
# Average Dice Score after Round 186: 0.1251
# --- Round 187 ---
# Average Dice Score after Round 187: 0.0784
# --- Round 188 ---
# Average Dice Score after Round 188: 0.0942
# --- Round 189 ---
# Average Dice Score after Round 189: 0.1462
# --- Round 190 ---
# Average Dice Score after Round 190: 0.0569
# --- Round 191 ---
# Average Dice Score after Round 191: 0.0650
# --- Round 192 ---
# Average Dice Score after Round 192: 0.1495
# --- Round 193 ---
# Average Dice Score after Round 193: 0.0687
# --- Round 194 ---
# Average Dice Score after Round 194: 0.0569
# --- Round 195 ---
# Average Dice Score after Round 195: 0.0532
# --- Round 196 ---
# Average Dice Score after Round 196: 0.1625
# --- Round 197 ---
# Average Dice Score after Round 197: 0.0382
# --- Round 198 ---
# Average Dice Score after Round 198: 0.0638
# --- Round 199 ---
# Average Dice Score after Round 199: 0.1638
# --- Round 200 ---
# Average Dice Score after Round 200: 0.0757
# Total communication cost: 7698.22 MB
# Total communication time: 15.66 seconds
# Total parameters exchanged: 1924548000

# %%
num_clients = 4
train_client_datasets, val_client_datasets = split_dataset_iid(train_ds, val_ds, num_clients)

#check the number of samples in each client
for i, client_data in enumerate(val_client_datasets):
    print(f"Client {i+1} has {len(client_data)} samples.")
# Out:
# Client 1 has 2 samples.
# Client 2 has 2 samples.
# Client 3 has 2 samples.
# Client 4 has 2 samples.

# %%
## KD iid

model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

student_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(8, 16, 32, 64),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

teacher_state_dict = torch.load(os.path.join(model_dir, "fedavg_r200_iid.pth"))

teacher_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
teacher_model.load_state_dict(teacher_state_dict['global_model_state'])

# FedAvg configuration
num_clients = 4  # Total number of clients
client_fraction = 0.5  # Fraction of clients selected per round
local_epochs = 2  # Number of epochs each client trains locally
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])

fedavg_iid = FedAvg(
    model=student_model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=0.5,
    local_epochs=2,
    batch_size=2,
    lr=1e-4,
    teacher_model=teacher_model,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedavg_iid.set_clients(train_client_datasets, val_client_datasets)

fedavg_iid.run(
    num_rounds=200,           
    post_pred=post_pred,     
    post_label=post_label,   
    dice_metric=dice_metric  
)

torch.save({
    'round_losses': fedavg_iid.round_loss_values,
    'dice_scores': fedavg_iid.dice_metric_values,
    'model size': fedavg_iid.communication_cost,
    'communication time': fedavg_iid.communication_time,
    'parameter count': fedavg_iid.param_count,
    'global_model_state': fedavg_iid.global_model.state_dict()
}, 'fedavg_kd_r200_iid.pth')
# Out:
# c:\Users\edmund\anaconda3\envs\pytorch\lib\site-packages\monai\networks\nets\unet.py:130: UserWarning: `len(strides) > len(channels) - 1`, the last 1 values of strides will not be used.
#   warnings.warn(f"`len(strides) > len(channels) - 1`, the last {delta} values of strides will not be used.")
# C:\Users\edmund\AppData\Local\Temp\ipykernel_15148\1618607495.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher_state_dict = torch.load(os.path.join(model_dir, "fedavg_r200_iid.pth"))
# --- Round 1 ---
# Average Dice Score after Round 1: 0.0130
# --- Round 2 ---
# Average Dice Score after Round 2: 0.0188
# --- Round 3 ---
# Average Dice Score after Round 3: 0.0273
# --- Round 4 ---
# Average Dice Score after Round 4: 0.0340
# --- Round 5 ---
# Average Dice Score after Round 5: 0.0390
# --- Round 6 ---
# Average Dice Score after Round 6: 0.0418
# --- Round 7 ---
# Average Dice Score after Round 7: 0.0479
# --- Round 8 ---
# Average Dice Score after Round 8: 0.0500
# --- Round 9 ---
# Average Dice Score after Round 9: 0.0526
# --- Round 10 ---
# Average Dice Score after Round 10: 0.0623
# --- Round 11 ---
# Average Dice Score after Round 11: 0.0646
# --- Round 12 ---
# Average Dice Score after Round 12: 0.0744
# --- Round 13 ---
# Average Dice Score after Round 13: 0.0745
# --- Round 14 ---
# Average Dice Score after Round 14: 0.0593
# --- Round 15 ---
# Average Dice Score after Round 15: 0.0643
# --- Round 16 ---
# Average Dice Score after Round 16: 0.0916
# --- Round 17 ---
# Average Dice Score after Round 17: 0.0753
# --- Round 18 ---
# Average Dice Score after Round 18: 0.0679
# --- Round 19 ---
# Average Dice Score after Round 19: 0.0780
# --- Round 20 ---
# Average Dice Score after Round 20: 0.0818
# --- Round 21 ---
# Average Dice Score after Round 21: 0.0775
# --- Round 22 ---
# Average Dice Score after Round 22: 0.0857
# --- Round 23 ---
# Average Dice Score after Round 23: 0.1033
# --- Round 24 ---
# Average Dice Score after Round 24: 0.0970
# --- Round 25 ---
# Average Dice Score after Round 25: 0.0879
# --- Round 26 ---
# Average Dice Score after Round 26: 0.0991
# --- Round 27 ---
# Average Dice Score after Round 27: 0.1158
# --- Round 28 ---
# Average Dice Score after Round 28: 0.1158
# --- Round 29 ---
# Average Dice Score after Round 29: 0.0761
# --- Round 30 ---
# Average Dice Score after Round 30: 0.1468
# --- Round 31 ---
# Average Dice Score after Round 31: 0.1567
# --- Round 32 ---
# Average Dice Score after Round 32: 0.1355
# --- Round 33 ---
# Average Dice Score after Round 33: 0.2334
# --- Round 34 ---
# Average Dice Score after Round 34: 0.0962
# --- Round 35 ---
# Average Dice Score after Round 35: 0.1048
# --- Round 36 ---
# Average Dice Score after Round 36: 0.0862
# --- Round 37 ---
# Average Dice Score after Round 37: 0.0839
# --- Round 38 ---
# Average Dice Score after Round 38: 0.0855
# --- Round 39 ---
# Average Dice Score after Round 39: 0.1536
# --- Round 40 ---
# Average Dice Score after Round 40: 0.1067
# --- Round 41 ---
# Average Dice Score after Round 41: 0.2231
# --- Round 42 ---
# Average Dice Score after Round 42: 0.1509
# --- Round 43 ---
# Average Dice Score after Round 43: 0.1193
# --- Round 44 ---
# Average Dice Score after Round 44: 0.2311
# --- Round 45 ---
# Average Dice Score after Round 45: 0.1851
# --- Round 46 ---
# Average Dice Score after Round 46: 0.0992
# --- Round 47 ---
# Average Dice Score after Round 47: 0.1046
# --- Round 48 ---
# Average Dice Score after Round 48: 0.1160
# --- Round 49 ---
# Average Dice Score after Round 49: 0.1070
# --- Round 50 ---
# Average Dice Score after Round 50: 0.0813
# --- Round 51 ---
# Average Dice Score after Round 51: 0.3713
# --- Round 52 ---
# Average Dice Score after Round 52: 0.1131
# --- Round 53 ---
# Average Dice Score after Round 53: 0.2614
# --- Round 54 ---
# Average Dice Score after Round 54: 0.0860
# --- Round 55 ---
# Average Dice Score after Round 55: 0.1397
# --- Round 56 ---
# Average Dice Score after Round 56: 0.1141
# --- Round 57 ---
# Average Dice Score after Round 57: 0.0967
# --- Round 58 ---
# Average Dice Score after Round 58: 0.1934
# --- Round 59 ---
# Average Dice Score after Round 59: 0.1028
# --- Round 60 ---
# Average Dice Score after Round 60: 0.1724
# --- Round 61 ---
# Average Dice Score after Round 61: 0.2974
# --- Round 62 ---
# Average Dice Score after Round 62: 0.1277
# --- Round 63 ---
# Average Dice Score after Round 63: 0.1938
# --- Round 64 ---
# Average Dice Score after Round 64: 0.1209
# --- Round 65 ---
# Average Dice Score after Round 65: 0.0988
# --- Round 66 ---
# Average Dice Score after Round 66: 0.1663
# --- Round 67 ---
# Average Dice Score after Round 67: 0.1289
# --- Round 68 ---
# Average Dice Score after Round 68: 0.1559
# --- Round 69 ---
# Average Dice Score after Round 69: 0.1172
# --- Round 70 ---
# Average Dice Score after Round 70: 0.1144
# --- Round 71 ---
# Average Dice Score after Round 71: 0.1874
# --- Round 72 ---
# Average Dice Score after Round 72: 0.3745
# --- Round 73 ---
# Average Dice Score after Round 73: 0.4185
# --- Round 74 ---
# Average Dice Score after Round 74: 0.2160
# --- Round 75 ---
# Average Dice Score after Round 75: 0.1324
# --- Round 76 ---
# Average Dice Score after Round 76: 0.4090
# --- Round 77 ---
# Average Dice Score after Round 77: 0.0955
# --- Round 78 ---
# Average Dice Score after Round 78: 0.1166
# --- Round 79 ---
# Average Dice Score after Round 79: 0.2473
# --- Round 80 ---
# Average Dice Score after Round 80: 0.1933
# --- Round 81 ---
# Average Dice Score after Round 81: 0.1975
# --- Round 82 ---
# Average Dice Score after Round 82: 0.2781
# --- Round 83 ---
# Average Dice Score after Round 83: 0.3007
# --- Round 84 ---
# Average Dice Score after Round 84: 0.1503
# --- Round 85 ---
# Average Dice Score after Round 85: 0.1317
# --- Round 86 ---
# Average Dice Score after Round 86: 0.1343
# --- Round 87 ---
# Average Dice Score after Round 87: 0.2406
# --- Round 88 ---
# Average Dice Score after Round 88: 0.1227
# --- Round 89 ---
# Average Dice Score after Round 89: 0.1262
# --- Round 90 ---
# Average Dice Score after Round 90: 0.1656
# --- Round 91 ---
# Average Dice Score after Round 91: 0.2394
# --- Round 92 ---
# Average Dice Score after Round 92: 0.5309
# --- Round 93 ---
# Average Dice Score after Round 93: 0.1541
# --- Round 94 ---
# Average Dice Score after Round 94: 0.1747
# --- Round 95 ---
# Average Dice Score after Round 95: 0.1098
# --- Round 96 ---
# Average Dice Score after Round 96: 0.3198
# --- Round 97 ---
# Average Dice Score after Round 97: 0.1851
# --- Round 98 ---
# Average Dice Score after Round 98: 0.3465
# --- Round 99 ---
# Average Dice Score after Round 99: 0.1515
# --- Round 100 ---
# Average Dice Score after Round 100: 0.2017
# --- Round 101 ---
# Average Dice Score after Round 101: 0.6123
# --- Round 102 ---
# Average Dice Score after Round 102: 0.2598
# --- Round 103 ---
# Average Dice Score after Round 103: 0.3684
# --- Round 104 ---
# Average Dice Score after Round 104: 0.4080
# --- Round 105 ---
# Average Dice Score after Round 105: 0.2858
# --- Round 106 ---
# Average Dice Score after Round 106: 0.6766
# --- Round 107 ---
# Average Dice Score after Round 107: 0.3325
# --- Round 108 ---
# Average Dice Score after Round 108: 0.2883
# --- Round 109 ---
# Average Dice Score after Round 109: 0.4350
# --- Round 110 ---
# Average Dice Score after Round 110: 0.4663
# --- Round 111 ---
# Average Dice Score after Round 111: 0.2816
# --- Round 112 ---
# Average Dice Score after Round 112: 0.2147
# --- Round 113 ---
# Average Dice Score after Round 113: 0.1713
# --- Round 114 ---
# Average Dice Score after Round 114: 0.2925
# --- Round 115 ---
# Average Dice Score after Round 115: 0.4392
# --- Round 116 ---
# Average Dice Score after Round 116: 0.3184
# --- Round 117 ---
# Average Dice Score after Round 117: 0.1985
# --- Round 118 ---
# Average Dice Score after Round 118: 0.5058
# --- Round 119 ---
# Average Dice Score after Round 119: 0.1689
# --- Round 120 ---
# Average Dice Score after Round 120: 0.6487
# --- Round 121 ---
# Average Dice Score after Round 121: 0.3794
# --- Round 122 ---
# Average Dice Score after Round 122: 0.4349
# --- Round 123 ---
# Average Dice Score after Round 123: 0.6084
# --- Round 124 ---
# Average Dice Score after Round 124: 0.6214
# --- Round 125 ---
# Average Dice Score after Round 125: 0.6041
# --- Round 126 ---
# Average Dice Score after Round 126: 0.6715
# --- Round 127 ---
# Average Dice Score after Round 127: 0.6936
# --- Round 128 ---
# Average Dice Score after Round 128: 0.3409
# --- Round 129 ---
# Average Dice Score after Round 129: 0.5032
# --- Round 130 ---
# Average Dice Score after Round 130: 0.2843
# --- Round 131 ---
# Average Dice Score after Round 131: 0.5768
# --- Round 132 ---
# Average Dice Score after Round 132: 0.4978
# --- Round 133 ---
# Average Dice Score after Round 133: 0.2491
# --- Round 134 ---
# Average Dice Score after Round 134: 0.6817
# --- Round 135 ---
# Average Dice Score after Round 135: 0.7439
# --- Round 136 ---
# Average Dice Score after Round 136: 0.2867
# --- Round 137 ---
# Average Dice Score after Round 137: 0.7805
# --- Round 138 ---
# Average Dice Score after Round 138: 0.5741
# --- Round 139 ---
# Average Dice Score after Round 139: 0.3661
# --- Round 140 ---
# Average Dice Score after Round 140: 0.8637
# --- Round 141 ---
# Average Dice Score after Round 141: 0.6509
# --- Round 142 ---
# Average Dice Score after Round 142: 0.8684
# --- Round 143 ---
# Average Dice Score after Round 143: 0.7956
# --- Round 144 ---
# Average Dice Score after Round 144: 0.6611
# --- Round 145 ---
# Average Dice Score after Round 145: 0.5232
# --- Round 146 ---
# Average Dice Score after Round 146: 0.6961
# --- Round 147 ---
# Average Dice Score after Round 147: 0.3779
# --- Round 148 ---
# Average Dice Score after Round 148: 0.8306
# --- Round 149 ---
# Average Dice Score after Round 149: 0.7767
# --- Round 150 ---
# Average Dice Score after Round 150: 0.8420
# --- Round 151 ---
# Average Dice Score after Round 151: 0.4825
# --- Round 152 ---
# Average Dice Score after Round 152: 0.7775
# --- Round 153 ---
# Average Dice Score after Round 153: 0.6106
# --- Round 154 ---
# Average Dice Score after Round 154: 0.7207
# --- Round 155 ---
# Average Dice Score after Round 155: 0.7424
# --- Round 156 ---
# Average Dice Score after Round 156: 0.7937
# --- Round 157 ---
# Average Dice Score after Round 157: 0.8328
# --- Round 158 ---
# Average Dice Score after Round 158: 0.7615
# --- Round 159 ---
# Average Dice Score after Round 159: 0.7122
# --- Round 160 ---
# Average Dice Score after Round 160: 0.7983
# --- Round 161 ---
# Average Dice Score after Round 161: 0.7762
# --- Round 162 ---
# Average Dice Score after Round 162: 0.6784
# --- Round 163 ---
# Average Dice Score after Round 163: 0.8304
# --- Round 164 ---
# Average Dice Score after Round 164: 0.7827
# --- Round 165 ---
# Average Dice Score after Round 165: 0.8370
# --- Round 166 ---
# Average Dice Score after Round 166: 0.4932
# --- Round 167 ---
# Average Dice Score after Round 167: 0.6480
# --- Round 168 ---
# Average Dice Score after Round 168: 0.8235
# --- Round 169 ---
# Average Dice Score after Round 169: 0.3363
# --- Round 170 ---
# Average Dice Score after Round 170: 0.7232
# --- Round 171 ---
# Average Dice Score after Round 171: 0.6457
# --- Round 172 ---
# Average Dice Score after Round 172: 0.6499
# --- Round 173 ---
# Average Dice Score after Round 173: 0.4154
# --- Round 174 ---
# Average Dice Score after Round 174: 0.8623
# --- Round 175 ---
# Average Dice Score after Round 175: 0.8851
# --- Round 176 ---
# Average Dice Score after Round 176: 0.5420
# --- Round 177 ---
# Average Dice Score after Round 177: 0.8604
# --- Round 178 ---
# Average Dice Score after Round 178: 0.9045
# --- Round 179 ---
# Average Dice Score after Round 179: 0.8737
# --- Round 180 ---
# Average Dice Score after Round 180: 0.8356
# --- Round 181 ---
# Average Dice Score after Round 181: 0.8258
# --- Round 182 ---
# Average Dice Score after Round 182: 0.8993
# --- Round 183 ---
# Average Dice Score after Round 183: 0.8488
# --- Round 184 ---
# Average Dice Score after Round 184: 0.3434
# --- Round 185 ---
# Average Dice Score after Round 185: 0.8749
# --- Round 186 ---
# Average Dice Score after Round 186: 0.8579
# --- Round 187 ---
# Average Dice Score after Round 187: 0.8564
# --- Round 188 ---
# Average Dice Score after Round 188: 0.8517
# --- Round 189 ---
# Average Dice Score after Round 189: 0.5892
# --- Round 190 ---
# Average Dice Score after Round 190: 0.8559
# --- Round 191 ---
# Average Dice Score after Round 191: 0.7406
# --- Round 192 ---
# Average Dice Score after Round 192: 0.8019
# --- Round 193 ---
# Average Dice Score after Round 193: 0.7649
# --- Round 194 ---
# Average Dice Score after Round 194: 0.8787
# --- Round 195 ---
# Average Dice Score after Round 195: 0.9035
# --- Round 196 ---
# Average Dice Score after Round 196: 0.8891
# --- Round 197 ---
# Average Dice Score after Round 197: 0.6653
# --- Round 198 ---
# Average Dice Score after Round 198: 0.8141
# --- Round 199 ---
# Average Dice Score after Round 199: 0.8815
# --- Round 200 ---
# Average Dice Score after Round 200: 0.6330
# Total communication cost: 478.12 MB
# Total communication time: 13.01 seconds
# Total parameters exchanged: 119524000

# %%
## No KD iid

fedavg_nkd_iid = FedAvg(
    model=model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=0.5,
    local_epochs=2,
    batch_size=2,
    lr=1e-4,
    teacher_model=None,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedavg_nkd_iid.set_clients(train_client_datasets, val_client_datasets)

fedavg_nkd_iid.run(
    num_rounds=200,           
    post_pred=post_pred,     
    post_label=post_label,   
    dice_metric=dice_metric  
)

torch.save({
    'round_losses': fedavg_nkd_iid.round_loss_values,
    'dice_scores': fedavg_nkd_iid.dice_metric_values,
    'model size': fedavg_nkd_iid.communication_cost,
    'communication time': fedavg_nkd_iid.communication_time,
    'parameter count': fedavg_nkd_iid.param_count,
    'global_model_state': fedavg_nkd_iid.global_model.state_dict()
}, 'fedavg_nkd_r200_iid.pth')

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedavg.round_loss_values[i],
        'dice_scores': fedavg.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedavg.communication_cost if i == 0 else '',
        'communication_time': fedavg.communication_time if i == 0 else '',
        'parameter_count': fedavg.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedavg_kd_r200_niid_plot.csv', index=False)

print("CSV file saved as 'fedavg_kd_r200_niid_plot.csv'")
df

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedavg_nkd.round_loss_values[i],
        'dice_scores': fedavg_nkd.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedavg_nkd.communication_cost if i == 0 else '',
        'communication_time': fedavg_nkd.communication_time if i == 0 else '',
        'parameter_count': fedavg_nkd.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedavg_nkd_r200_niid_plot.csv', index=False)

print("CSV file saved as 'fedavg_nkd_r200_niid_plot.csv'")
df
# Out:
# CSV file saved as 'fedavg_nkd_r200_niid_plot.csv'
#      round  round_losses dice_scores  model_size communication_time  \
# 0        1      0.679961              7698219200          15.656538
# 1        2      0.664540    0.016262
# 2        3      0.642148
# 3        4      0.630550    0.032777
# 4        5      0.622092
# ..     ...           ...         ...         ...                ...
# 195    196      0.250318     0.16247
# 196    197      0.226813
# 197    198      0.237786    0.063828
# 198    199      0.233401
# 199    200      0.245213    0.075666
#
#     parameter_count
# 0        1924548000
# 1
# 2
# 3
# 4
# ..              ...
# 195
# 196
# 197
# 198
# 199
#
# [200 rows x 6 columns]

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedavg_iid.round_loss_values[i],
        'dice_scores': fedavg_iid.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedavg_iid.communication_cost if i == 0 else '',
        'communication_time': fedavg_iid.communication_time if i == 0 else '',
        'parameter_count': fedavg_iid.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedavg_kd_r200_iid_plot.csv', index=False)

print("CSV file saved as 'fedavg_kd_r200_iid_plot.csv'")
df
# Out:
# CSV file saved as 'fedavg_kd_r200_iid_plot.csv'
#      round  round_losses dice_scores model_size communication_time  \
# 0        1      0.623015              478116800          13.011005
# 1        2      0.605093    0.018751
# 2        3      0.603996
# 3        4      0.591854     0.03398
# 4        5      0.584480
# ..     ...           ...         ...        ...                ...
# 195    196      0.218153    0.889146
# 196    197      0.218031
# 197    198      0.203979    0.814147
# 198    199      0.232753
# 199    200      0.220739    0.632969
#
#     parameter_count
# 0         119524000
# 1
# 2
# 3
# 4
# ..              ...
# 195
# 196
# 197
# 198
# 199
#
# [200 rows x 6 columns]

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedavg_nkd_iid.round_loss_values[i],
        'dice_scores': fedavg_nkd_iid.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedavg_nkd_iid.communication_cost if i == 0 else '',
        'communication_time': fedavg_nkd_iid.communication_time if i == 0 else '',
        'parameter_count': fedavg_nkd_iid.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedavg_nkd_r200_iid_plot.csv', index=False)

print("CSV file saved as 'fedavg_nkd_r200_iid_plot.csv'")
df
