# %%
# %matplotlib inline
from monai.utils import first, set_determinism
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
)
from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob
import tarfile
import numpy as np
from torch.utils.data import Subset
import copy
set_determinism(seed=0)
import torch.nn.functional as F
import time
import pandas as pd


#print_config()

# %% [markdown]
# # Read data

# %%
# read data
def get_spleen_dataset(data_dir):
    train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
    print(train_images)
    train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))
    data_dicts = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]
    train_files, val_files = data_dicts[:-9], data_dicts[-9:]
    
    train_transforms = Compose(
        [
            LoadImaged(keys=["image", "label"]),
            EnsureChannelFirstd(keys=["image", "label"]),
            ScaleIntensityRanged(
                keys=["image"],
                a_min=-57,
                a_max=164,
                b_min=0.0,
                b_max=1.0,
                clip=True,
            ),
            CropForegroundd(keys=["image", "label"], source_key="image"),
            Orientationd(keys=["image", "label"], axcodes="RAS"),
            Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
            RandCropByPosNegLabeld(
                keys=["image", "label"],
                label_key="label",
                spatial_size=(96, 96, 96),
                pos=1,
                neg=1,
                num_samples=4,
                image_key="image",
                image_threshold=0,
            ),
            # user can also add other random transforms
            # RandAffined(
            #     keys=['image', 'label'],
            #     mode=('bilinear', 'nearest'),
            #     prob=1.0, spatial_size=(96, 96, 96),
            #     rotate_range=(0, 0, np.pi/15),
            #     scale_range=(0.1, 0.1, 0.1)),
        ]
    )
    val_transforms = Compose(
        [
            LoadImaged(keys=["image", "label"]),
            EnsureChannelFirstd(keys=["image", "label"]),
            ScaleIntensityRanged(
                keys=["image"],
                a_min=-57,
                a_max=164,
                b_min=0.0,
                b_max=1.0,
                clip=True,
            ),
            CropForegroundd(keys=["image", "label"], source_key="image"),
            Orientationd(keys=["image", "label"], axcodes="RAS"),
            Spacingd(keys=["image", "label"], pixdim=(1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        ]
    )
    
    train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4)
    val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4)
    
    return train_ds, val_ds

# %% [markdown]
# # FedCluster with knowledge distillation

# %%
class FedCluster:
    def __init__(self, model, loss_function, device, num_clients, client_fraction, local_epochs, batch_size, lr=1e-4, num_clusters=2, teacher_model=None, alpha=0.5, temperature=2.0):
        self.global_model = model
        self.loss_function = loss_function
        self.device = device
        self.num_clients = num_clients
        self.client_fraction = client_fraction
        self.local_epochs = local_epochs
        self.batch_size = batch_size
        self.lr = lr
        self.num_clusters = num_clusters
        self.clients = []  
        self.clusters = []
        self.teacher_model = teacher_model.to(device) if teacher_model else None
        self.alpha = alpha
        self.temperature = temperature  
        
        self.round_loss_values = []  
        self.dice_metric_values = []  

    def set_clients(self, train_datasets, val_datasets):
        # Create a list of dictionaries with train and val datasets for each client
        self.clients = [{"train": train, "val": val} for train, val in zip(train_datasets, val_datasets)]
        self.create_clusters()

        # Track communication costs
        self.communication_cost = 0  # For KD-based lightweight models
        self.communication_time = 0  # Total time spent in communication (in seconds)
        self.param_count = 0  # Total number of parameters exchanged

    def create_clusters(self):
        # Randomly group clients into clusters
        client_ids = np.arange(self.num_clients)
        np.random.shuffle(client_ids)
        cluster_size = self.num_clients // self.num_clusters
        self.clusters = [client_ids[i:i + cluster_size] for i in range(0, len(client_ids), cluster_size)]

    def calculate_model_size(self, model_state_dict):
        """
        Calculate the size of the model state in bytes.
        """
        return sum(param.numel() * param.element_size() for param in model_state_dict.values())
    
    def calculate_parameter_count(self, model_state_dict):
        """
        Count the number of parameters in the model state.
        """
        return sum(param.numel() for param in model_state_dict.values())

    def distillation_loss(self, student_logits, teacher_logits):
        """
        Compute the distillation loss using KL divergence between softened logits.
        Args:
            student_logits: Logits from the student model.
            teacher_logits: Logits from the teacher model.
        """
        student_soft = F.log_softmax(student_logits / self.temperature, dim=1)
        teacher_soft = F.softmax(teacher_logits / self.temperature, dim=1)
        return F.kl_div(student_soft, teacher_soft, reduction="batchmean") * (self.temperature ** 2)

    def client_update(self, client_data):
        """
        Perform local training on a client.
        """
        local_model = copy.deepcopy(self.global_model)
        local_model.train()
        local_model.to(self.device)
        local_train_start = time.time()

        # Freeze the teacher model if provided
        if self.teacher_model:
            self.teacher_model.eval()

        train_loader = DataLoader(client_data["train"], batch_size=self.batch_size, shuffle=True, num_workers=4)
        optimizer = torch.optim.Adam(local_model.parameters(), lr=self.lr)

        total_loss = 0
        num_batches = 0
        
        for _ in range(self.local_epochs):
            for batch_data in train_loader:
                inputs, labels = (
                    batch_data["image"].to(self.device),
                    batch_data["label"].to(self.device),
                )
                optimizer.zero_grad()
                outputs = local_model(inputs)

                # Compute Dice loss
                dice_loss = self.loss_function(outputs, labels)

                if self.teacher_model:
                    with torch.no_grad():
                        teacher_outputs = self.teacher_model(inputs)
                    
                    # Compute distillation loss
                    distill_loss = self.distillation_loss(outputs, teacher_outputs)
                    distill_loss = torch.sigmoid(distill_loss)

                    # Combine Dice loss and distillation loss
                    task_specific_loss = dice_loss.item()
                    loss = self.alpha * distill_loss + (1 - self.alpha) * dice_loss
                else:
                    loss = dice_loss

                loss.backward()
                optimizer.step()

                if self.teacher_model:
                    total_loss += task_specific_loss
                else:
                    total_loss += loss.item()
                num_batches += 1
        
        local_train_end = time.time()

        loss_per_client = total_loss / num_batches if num_batches > 0 else 0

        # Calculate model size for communication cost
        model_size = self.calculate_model_size(local_model.state_dict())

        # Calculate number of parameters passed for communication cost
        num_params = self.calculate_parameter_count(local_model.state_dict())

        local_train_time = local_train_end - local_train_start

        return local_model.state_dict(), loss_per_client, model_size, num_params, local_train_time

    def aggregate_updates(self, client_updates, client_sizes):
        """
        Aggregate client updates to update the global model.
        """
        global_weights = copy.deepcopy(self.global_model.state_dict())
        total_size = sum(client_sizes)

        for key in global_weights.keys():
            global_weights[key] = sum(
                client_updates[i][key] * client_sizes[i] / total_size for i in range(len(client_updates))
            )

        return global_weights

    def run(self, num_rounds, post_pred, post_label, dice_metric):
        """
        Run the FedCluster algorithm.
        """
        global_weights = self.global_model.state_dict()

        self.communication_time = 0  # Reset communication time
        self.param_count = 0  # Reset parameter count

        for round_num in range(num_rounds):
            print(f"--- Round {round_num + 1} ---")
            for cluster_idx, cluster in enumerate(self.clusters):
                print(f"Processing Cluster {cluster_idx + 1}")

                # Randomly select clients from the cluster
                num_selected_clients = max(int(self.client_fraction * len(cluster)), 1)
                selected_clients = np.random.choice(cluster, num_selected_clients, replace=False)

                client_updates = []
                client_sizes = []
                total_loss = 0

                round_start_time = time.time()

                # Each selected client performs local training
                for client_id in selected_clients:
                    client_data = self.clients[client_id]
                    client_size = len(client_data["train"])
                    client_sizes.append(client_size)

                    updated_weights, loss_per_client, model_size, num_params, local_train_time = self.client_update(client_data)
                    client_updates.append(updated_weights)
                    total_loss += loss_per_client

                    # Track communication cost
                    self.communication_time -= local_train_time
                    # print(local_train_time, self.communication_time)
                    self.communication_cost += model_size
                    self.param_count += num_params
                
                round_end_time = time.time()

                self.communication_time += (round_end_time - round_start_time)
                # print(round_end_time - round_start_time, self.communication_time)

                # Aggregate updates from the cluster
                global_weights = self.aggregate_updates(client_updates, client_sizes)
                self.global_model.load_state_dict(global_weights)

            # Evaluate the global model on all validation datasets
            avg_dice_score = self.evaluate_global_model(
                [client["val"] for client in self.clients],
                post_pred,
                post_label,
                dice_metric,
            )
            print(f"Average Dice Score after Round {round_num + 1}: {avg_dice_score:.4f}")

            self.dice_metric_values.append(avg_dice_score)
            avg_loss_per_round = total_loss / len(selected_clients) if len(selected_clients) > 0 else 0
            self.round_loss_values.append(avg_loss_per_round)

        # Print communication costs
        print(f"Total communication cost: {self.communication_cost / 1e6:.2f} MB")
        print(f"Total communication time: {self.communication_time:.2f} seconds")
        print(f"Total parameters exchanged: {self.param_count}")
            
    def evaluate_global_model(self, val_datasets, post_pred, post_label, dice_metric):
        """
        Evaluate the global model on all clients' validation datasets.
        """
        self.global_model.eval()
        dice_scores = []

        for val_data in val_datasets:
            val_loader = DataLoader(val_data, batch_size=1, num_workers=4)
            with torch.no_grad():
                for batch_data in val_loader:
                    val_inputs, val_labels = (
                        batch_data["image"].to(self.device),
                        batch_data["label"].to(self.device),
                    )
                    roi_size = (160, 160, 160)
                    sw_batch_size = 4
                    val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, self.global_model)
                    val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                    val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                    dice_metric(y_pred=val_outputs, y=val_labels)

                dice_score = dice_metric.aggregate().item()
                dice_scores.append(dice_score)
                dice_metric.reset()

        return np.mean(dice_scores)

# %%
def split_dataset_iid(train_dataset, val_dataset, num_clients):
    #make the dataset evenly divisible by removing the last elements if needed
    train_dataset = train_dataset[:len(train_dataset) - len(train_dataset) % num_clients]
    val_dataset = val_dataset[:len(val_dataset) - len(val_dataset) % num_clients]
    
    #split the dataset into num_clients subsets randomly 
    train_indices = np.random.permutation(len(train_dataset))
    val_indices = np.random.permutation(len(val_dataset))
    train_client_splits = np.array_split(train_indices, num_clients)
    val_client_splits = np.array_split(val_indices, num_clients)
    
    #create a list of subsets
    train_client_datasets = [Subset(train_dataset, split) for split in train_client_splits]
    val_client_datasets = [Subset(val_dataset, split) for split in val_client_splits]
    
    return train_client_datasets, val_client_datasets

# %%
def split_dataset_non_iid(train_dataset, val_dataset, num_clients):
    if len(train_dataset) % num_clients != 0 or len(val_dataset) % num_clients != 0:
         #split the dataset into num_clients subsets randomly 
        train_indices = np.random.permutation(len(train_dataset))
        val_indices = np.random.permutation(len(val_dataset))
        train_client_splits = np.array_split(train_indices, num_clients)
        val_client_splits = np.array_split(val_indices, num_clients)
        
        #create a list of subsets
        train_client_datasets = [Subset(train_dataset, split) for split in train_client_splits]
        val_client_datasets = [Subset(val_dataset, split) for split in val_client_splits]
        
        return train_client_datasets, val_client_datasets
    
    else: 
        while len(train_dataset) % num_clients == 0:
            train_dataset = train_dataset[:len(train_dataset) - 1]
        return split_dataset_non_iid(train_dataset, val_dataset, num_clients)

# %%
#set the data path
root_dir = os.path.dirname(os.path.dirname(os.path.abspath("federated_learning")))
data_dir = os.path.join(root_dir, "data/raw/Task09_Spleen/")
model_dir = os.path.join(root_dir, "models_gpu")

# %%
#load the entire dataset
train_ds, val_ds = get_spleen_dataset(data_dir)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=4)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=4)

#split the dataset into num_clients IID subsets
num_clients = 4
train_client_datasets, val_client_datasets = split_dataset_iid(train_ds, val_ds, num_clients)
# Out:
# c:\Users\edmund\anaconda3\envs\pytorch\lib\site-packages\monai\utils\deprecate_utils.py:321: FutureWarning: monai.transforms.croppad.dictionary CropForegroundd.__init__:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)
# ['c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_10.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_12.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_13.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_14.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_16.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_17.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_18.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_19.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_2.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_20.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_21.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_22.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_24.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_25.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_26.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_27.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_28.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_29.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_3.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_31.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_32.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_33.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_38.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_40.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_41.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_44.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_45.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_46.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_47.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_49.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_52.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_53.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_56.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_59.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_6.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\federated_learning\\data/raw/Task09_Spleen/imagesTr\\spleen_60.nii.gz', 'c:\\Users\\edmund\\Documents\\mlsys\\fede ...
# Loading dataset: 100%|██████████| 32/32 [00:31<00:00,  1.01it/s]
# Loading dataset: 100%|██████████| 9/9 [00:07<00:00,  1.25it/s]

# %% [markdown]
# # Model training

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# %%
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

student_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(8, 16, 32, 64),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

teacher_state_dict = torch.load(os.path.join(model_dir, "fedc_r200_niid.pth"))

teacher_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
teacher_model.load_state_dict(teacher_state_dict['global_model_state'])

# FedAvg configuration
num_clients = 4  # Total number of clients
#num_rounds = 2  # Number of communication rounds
client_fraction = 0.5  # Fraction of clients selected per round
local_epochs = 2  # Number of epochs each client trains locally
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])

fedcluster = FedCluster(
    model=student_model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=client_fraction,
    local_epochs=local_epochs,
    batch_size=2,
    lr=1e-4,
    num_clusters=2,
    teacher_model=teacher_model,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedcluster.set_clients(train_client_datasets, val_client_datasets)

num_rounds = 200
fedcluster.run(num_rounds, post_pred, post_label, dice_metric)

torch.save({
    'round_losses': fedcluster.round_loss_values,
    'dice_scores': fedcluster.dice_metric_values,
    'model size': fedcluster.communication_cost,
    'communication time': fedcluster.communication_time,
    'parameter count': fedcluster.param_count,
    'global_model_state': fedcluster.global_model.state_dict()
}, 'fedc_kd_r200_niid.pth')
# Out:
# c:\Users\edmund\anaconda3\envs\pytorch\lib\site-packages\monai\networks\nets\unet.py:130: UserWarning: `len(strides) > len(channels) - 1`, the last 1 values of strides will not be used.
#   warnings.warn(f"`len(strides) > len(channels) - 1`, the last {delta} values of strides will not be used.")
# C:\Users\edmund\AppData\Local\Temp\ipykernel_13236\809242348.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher_state_dict = torch.load(os.path.join(model_dir, "fedc_r200_niid.pth"))
# --- Round 1 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 1: 0.0181
# --- Round 2 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 2: 0.0334
# --- Round 3 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 3: 0.0429
# --- Round 4 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 4: 0.0592
# --- Round 5 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 5: 0.0596
# --- Round 6 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 6: 0.0661
# --- Round 7 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 7: 0.0789
# --- Round 8 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 8: 0.0877
# --- Round 9 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 9: 0.0889
# --- Round 10 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 10: 0.1066
# --- Round 11 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 11: 0.1888
# --- Round 12 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 12: 0.1689
# --- Round 13 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 13: 0.1539
# --- Round 14 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 14: 0.1529
# --- Round 15 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 15: 0.0817
# --- Round 16 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 16: 0.1795
# --- Round 17 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 17: 0.1068
# --- Round 18 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 18: 0.1375
# --- Round 19 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 19: 0.2197
# --- Round 20 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 20: 0.1573
# --- Round 21 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 21: 0.1821
# --- Round 22 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 22: 0.3709
# --- Round 23 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 23: 0.0890
# --- Round 24 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 24: 0.0820
# --- Round 25 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 25: 0.2150
# --- Round 26 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 26: 0.1906
# --- Round 27 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 27: 0.2035
# --- Round 28 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 28: 0.1240
# --- Round 29 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 29: 0.1426
# --- Round 30 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 30: 0.1606
# --- Round 31 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 31: 0.1079
# --- Round 32 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 32: 0.1654
# --- Round 33 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 33: 0.4666
# --- Round 34 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 34: 0.1826
# --- Round 35 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 35: 0.1085
# --- Round 36 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 36: 0.1697
# --- Round 37 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 37: 0.2310
# --- Round 38 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 38: 0.2822
# --- Round 39 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 39: 0.2267
# --- Round 40 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 40: 0.2344
# --- Round 41 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 41: 0.1766
# --- Round 42 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 42: 0.1924
# --- Round 43 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 43: 0.2059
# --- Round 44 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 44: 0.2578
# --- Round 45 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 45: 0.6681
# --- Round 46 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 46: 0.2852
# --- Round 47 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 47: 0.4845
# --- Round 48 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 48: 0.4265
# --- Round 49 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 49: 0.1844
# --- Round 50 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 50: 0.1963
# --- Round 51 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 51: 0.6993
# --- Round 52 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 52: 0.6272
# --- Round 53 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 53: 0.5511
# --- Round 54 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 54: 0.2876
# --- Round 55 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 55: 0.5005
# --- Round 56 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 56: 0.3148
# --- Round 57 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 57: 0.3040
# --- Round 58 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 58: 0.1480
# --- Round 59 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 59: 0.2521
# --- Round 60 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 60: 0.8043
# --- Round 61 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 61: 0.6683
# --- Round 62 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 62: 0.6502
# --- Round 63 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 63: 0.5748
# --- Round 64 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 64: 0.7132
# --- Round 65 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 65: 0.6833
# --- Round 66 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 66: 0.3743
# --- Round 67 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 67: 0.4881
# --- Round 68 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 68: 0.6667
# --- Round 69 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 69: 0.6715
# --- Round 70 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 70: 0.7366
# --- Round 71 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 71: 0.6366
# --- Round 72 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 72: 0.6620
# --- Round 73 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 73: 0.4863
# --- Round 74 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 74: 0.4040
# --- Round 75 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 75: 0.7247
# --- Round 76 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 76: 0.5555
# --- Round 77 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 77: 0.6815
# --- Round 78 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 78: 0.6928
# --- Round 79 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 79: 0.8232
# --- Round 80 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 80: 0.6725
# --- Round 81 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 81: 0.8026
# --- Round 82 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 82: 0.6391
# --- Round 83 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 83: 0.7514
# --- Round 84 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 84: 0.3726
# --- Round 85 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 85: 0.8212
# --- Round 86 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 86: 0.8157
# --- Round 87 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 87: 0.7189
# --- Round 88 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 88: 0.6036
# --- Round 89 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 89: 0.8573
# --- Round 90 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 90: 0.8073
# --- Round 91 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 91: 0.8355
# --- Round 92 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 92: 0.8722
# --- Round 93 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 93: 0.5288
# --- Round 94 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 94: 0.7187
# --- Round 95 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 95: 0.6233
# --- Round 96 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 96: 0.8508
# --- Round 97 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 97: 0.7226
# --- Round 98 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 98: 0.8139
# --- Round 99 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 99: 0.8688
# --- Round 100 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 100: 0.7751
# --- Round 101 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 101: 0.7674
# --- Round 102 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 102: 0.7710
# --- Round 103 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 103: 0.8235
# --- Round 104 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 104: 0.7358
# --- Round 105 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 105: 0.6888
# --- Round 106 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 106: 0.8499
# --- Round 107 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 107: 0.7679
# --- Round 108 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 108: 0.8555
# --- Round 109 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 109: 0.6250
# --- Round 110 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 110: 0.8188
# --- Round 111 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 111: 0.8245
# --- Round 112 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 112: 0.8748
# --- Round 113 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 113: 0.8444
# --- Round 114 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 114: 0.7587
# --- Round 115 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 115: 0.8400
# --- Round 116 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 116: 0.8842
# --- Round 117 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 117: 0.5295
# --- Round 118 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 118: 0.7127
# --- Round 119 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 119: 0.8432
# --- Round 120 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 120: 0.8911
# --- Round 121 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 121: 0.8686
# --- Round 122 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 122: 0.8949
# --- Round 123 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 123: 0.8782
# --- Round 124 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 124: 0.8291
# --- Round 125 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 125: 0.9007
# --- Round 126 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 126: 0.8359
# --- Round 127 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 127: 0.8963
# --- Round 128 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 128: 0.8582
# --- Round 129 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 129: 0.8648
# --- Round 130 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 130: 0.9061
# --- Round 131 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 131: 0.8805
# --- Round 132 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 132: 0.8819
# --- Round 133 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 133: 0.9002
# --- Round 134 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 134: 0.7650
# --- Round 135 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 135: 0.9056
# --- Round 136 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 136: 0.9046
# --- Round 137 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 137: 0.6736
# --- Round 138 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 138: 0.8937
# --- Round 139 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 139: 0.9128
# --- Round 140 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 140: 0.8884
# --- Round 141 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 141: 0.9094
# --- Round 142 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 142: 0.8725
# --- Round 143 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 143: 0.8821
# --- Round 144 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 144: 0.8963
# --- Round 145 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 145: 0.8333
# --- Round 146 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 146: 0.8242
# --- Round 147 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 147: 0.8768
# --- Round 148 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 148: 0.8826
# --- Round 149 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 149: 0.9232
# --- Round 150 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 150: 0.8942
# --- Round 151 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 151: 0.7923
# --- Round 152 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 152: 0.9225
# --- Round 153 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 153: 0.8849
# --- Round 154 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 154: 0.8266
# --- Round 155 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 155: 0.9127
# --- Round 156 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 156: 0.9000
# --- Round 157 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 157: 0.8685
# --- Round 158 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 158: 0.9173
# --- Round 159 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 159: 0.9140
# --- Round 160 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 160: 0.7941
# --- Round 161 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 161: 0.6333
# --- Round 162 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 162: 0.8986
# --- Round 163 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 163: 0.8595
# --- Round 164 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 164: 0.8855
# --- Round 165 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 165: 0.8374
# --- Round 166 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 166: 0.8089
# --- Round 167 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 167: 0.8576
# --- Round 168 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 168: 0.8704
# --- Round 169 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 169: 0.8964
# --- Round 170 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 170: 0.9055
# --- Round 171 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 171: 0.6990
# --- Round 172 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 172: 0.9179
# --- Round 173 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 173: 0.8571
# --- Round 174 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 174: 0.8482
# --- Round 175 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 175: 0.8785
# --- Round 176 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 176: 0.8655
# --- Round 177 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 177: 0.7273
# --- Round 178 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 178: 0.8756
# --- Round 179 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 179: 0.6293
# --- Round 180 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 180: 0.7378
# --- Round 181 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 181: 0.9081
# --- Round 182 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 182: 0.8290
# --- Round 183 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 183: 0.7794
# --- Round 184 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 184: 0.8694
# --- Round 185 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 185: 0.8252
# --- Round 186 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 186: 0.8857
# --- Round 187 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 187: 0.8834
# --- Round 188 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 188: 0.8938
# --- Round 189 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 189: 0.8577
# --- Round 190 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 190: 0.8869
# --- Round 191 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 191: 0.9147
# --- Round 192 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 192: 0.8485
# --- Round 193 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 193: 0.8978
# --- Round 194 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 194: 0.8768
# --- Round 195 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 195: 0.9154
# --- Round 196 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 196: 0.9239
# --- Round 197 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 197: 0.9127
# --- Round 198 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 198: 0.9279
# --- Round 199 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 199: 0.8911
# --- Round 200 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 200: 0.9137
# Total communication cost: 478.12 MB
# Total communication time: 14.47 seconds
# Total parameters exchanged: 119524000

# %%
fedcluster_nkd = FedCluster(
    model=model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=client_fraction,
    local_epochs=local_epochs,
    batch_size=2,
    lr=1e-4,
    num_clusters=2,
    teacher_model=None,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedcluster_nkd.set_clients(train_client_datasets, val_client_datasets)

num_rounds = 200     
fedcluster_nkd.run(num_rounds, post_pred, post_label, dice_metric)

torch.save({
    'round_losses': fedcluster_nkd.round_loss_values,
    'dice_scores': fedcluster_nkd.dice_metric_values,
    'model size': fedcluster_nkd.communication_cost,
    'communication time': fedcluster_nkd.communication_time,
    'parameter count': fedcluster_nkd.param_count,
    'global_model_state': fedcluster_nkd.global_model.state_dict()
}, 'fedc_nkd_r200_niid.pth')
# Out:
# --- Round 1 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 1: 0.0149
# --- Round 2 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 2: 0.0322
# --- Round 3 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 3: 0.0373
# --- Round 4 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 4: 0.0416
# --- Round 5 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 5: 0.0480
# --- Round 6 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 6: 0.0486
# --- Round 7 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 7: 0.0521
# --- Round 8 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 8: 0.0420
# --- Round 9 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 9: 0.0497
# --- Round 10 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 10: 0.0548
# --- Round 11 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 11: 0.0533
# --- Round 12 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 12: 0.0895
# --- Round 13 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 13: 0.0759
# --- Round 14 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 14: 0.0642
# --- Round 15 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 15: 0.0505
# --- Round 16 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 16: 0.0524
# --- Round 17 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 17: 0.0628
# --- Round 18 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 18: 0.0610
# --- Round 19 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 19: 0.0480
# --- Round 20 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 20: 0.0673
# --- Round 21 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 21: 0.0409
# --- Round 22 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 22: 0.0976
# --- Round 23 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 23: 0.0593
# --- Round 24 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 24: 0.0617
# --- Round 25 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 25: 0.0433
# --- Round 26 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 26: 0.0466
# --- Round 27 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 27: 0.0420
# --- Round 28 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 28: 0.0520
# --- Round 29 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 29: 0.0377
# --- Round 30 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 30: 0.0335
# --- Round 31 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 31: 0.0676
# --- Round 32 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 32: 0.0408
# --- Round 33 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 33: 0.0341
# --- Round 34 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 34: 0.0354
# --- Round 35 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 35: 0.0302
# --- Round 36 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 36: 0.0543
# --- Round 37 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 37: 0.0566
# --- Round 38 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 38: 0.0564
# --- Round 39 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 39: 0.0324
# --- Round 40 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 40: 0.0511
# --- Round 41 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 41: 0.0419
# --- Round 42 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 42: 0.0569
# --- Round 43 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 43: 0.0256
# --- Round 44 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 44: 0.0300
# --- Round 45 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 45: 0.0312
# --- Round 46 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 46: 0.0389
# --- Round 47 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 47: 0.0305
# --- Round 48 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 48: 0.0561
# --- Round 49 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 49: 0.0305
# --- Round 50 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 50: 0.0321
# --- Round 51 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 51: 0.0319
# --- Round 52 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 52: 0.0319
# --- Round 53 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 53: 0.0366
# --- Round 54 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 54: 0.0518
# --- Round 55 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 55: 0.0312
# --- Round 56 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 56: 0.1200
# --- Round 57 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 57: 0.0292
# --- Round 58 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 58: 0.0316
# --- Round 59 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 59: 0.0601
# --- Round 60 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 60: 0.0277
# --- Round 61 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 61: 0.0463
# --- Round 62 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 62: 0.0333
# --- Round 63 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 63: 0.0352
# --- Round 64 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 64: 0.0354
# --- Round 65 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 65: 0.0422
# --- Round 66 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 66: 0.0499
# --- Round 67 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 67: 0.0280
# --- Round 68 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 68: 0.0459
# --- Round 69 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 69: 0.0343
# --- Round 70 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 70: 0.0386
# --- Round 71 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 71: 0.0337
# --- Round 72 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 72: 0.0527
# --- Round 73 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 73: 0.0406
# --- Round 74 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 74: 0.0450
# --- Round 75 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 75: 0.0661
# --- Round 76 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 76: 0.0400
# --- Round 77 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 77: 0.0461
# --- Round 78 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 78: 0.0878
# --- Round 79 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 79: 0.0577
# --- Round 80 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 80: 0.0611
# --- Round 81 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 81: 0.0424
# --- Round 82 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 82: 0.0458
# --- Round 83 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 83: 0.0392
# --- Round 84 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 84: 0.0537
# --- Round 85 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 85: 0.0301
# --- Round 86 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 86: 0.0507
# --- Round 87 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 87: 0.0587
# --- Round 88 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 88: 0.0439
# --- Round 89 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 89: 0.0627
# --- Round 90 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 90: 0.0618
# --- Round 91 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 91: 0.0553
# --- Round 92 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 92: 0.0474
# --- Round 93 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 93: 0.0362
# --- Round 94 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 94: 0.0447
# --- Round 95 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 95: 0.0501
# --- Round 96 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 96: 0.0623
# --- Round 97 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 97: 0.0567
# --- Round 98 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 98: 0.0412
# --- Round 99 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 99: 0.0708
# --- Round 100 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 100: 0.0534
# --- Round 101 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 101: 0.0551
# --- Round 102 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 102: 0.0500
# --- Round 103 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 103: 0.0365
# --- Round 104 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 104: 0.0677
# --- Round 105 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 105: 0.0341
# --- Round 106 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 106: 0.0474
# --- Round 107 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 107: 0.0614
# --- Round 108 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 108: 0.0677
# --- Round 109 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 109: 0.0598
# --- Round 110 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 110: 0.1231
# --- Round 111 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 111: 0.0612
# --- Round 112 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 112: 0.0299
# --- Round 113 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 113: 0.0446
# --- Round 114 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 114: 0.0652
# --- Round 115 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 115: 0.0743
# --- Round 116 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 116: 0.0632
# --- Round 117 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 117: 0.0990
# --- Round 118 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 118: 0.0506
# --- Round 119 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 119: 0.0723
# --- Round 120 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 120: 0.1066
# --- Round 121 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 121: 0.1812
# --- Round 122 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 122: 0.4132
# --- Round 123 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 123: 0.0652
# --- Round 124 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 124: 0.0674
# --- Round 125 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 125: 0.0886
# --- Round 126 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 126: 0.3080
# --- Round 127 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 127: 0.1721
# --- Round 128 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 128: 0.2139
# --- Round 129 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 129: 0.3453
# --- Round 130 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 130: 0.3750
# --- Round 131 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 131: 0.7514
# --- Round 132 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 132: 0.1138
# --- Round 133 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 133: 0.2093
# --- Round 134 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 134: 0.0806
# --- Round 135 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 135: 0.5026
# --- Round 136 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 136: 0.6436
# --- Round 137 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 137: 0.7516
# --- Round 138 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 138: 0.5601
# --- Round 139 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 139: 0.4843
# --- Round 140 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 140: 0.6879
# --- Round 141 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 141: 0.8554
# --- Round 142 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 142: 0.8121
# --- Round 143 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 143: 0.7288
# --- Round 144 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 144: 0.7549
# --- Round 145 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 145: 0.8509
# --- Round 146 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 146: 0.9281
# --- Round 147 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 147: 0.8559
# --- Round 148 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 148: 0.8975
# --- Round 149 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 149: 0.7074
# --- Round 150 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 150: 0.1654
# --- Round 151 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 151: 0.9188
# --- Round 152 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 152: 0.7136
# --- Round 153 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 153: 0.8411
# --- Round 154 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 154: 0.7452
# --- Round 155 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 155: 0.9106
# --- Round 156 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 156: 0.6080
# --- Round 157 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 157: 0.8005
# --- Round 158 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 158: 0.9140
# --- Round 159 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 159: 0.4628
# --- Round 160 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 160: 0.3509
# --- Round 161 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 161: 0.0938
# --- Round 162 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 162: 0.4384
# --- Round 163 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 163: 0.9028
# --- Round 164 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 164: 0.9065
# --- Round 165 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 165: 0.8777
# --- Round 166 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 166: 0.9306
# --- Round 167 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 167: 0.9319
# --- Round 168 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 168: 0.8604
# --- Round 169 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 169: 0.8987
# --- Round 170 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 170: 0.9339
# --- Round 171 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 171: 0.9327
# --- Round 172 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 172: 0.8156
# --- Round 173 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 173: 0.8360
# --- Round 174 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 174: 0.5669
# --- Round 175 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 175: 0.9253
# --- Round 176 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 176: 0.8436
# --- Round 177 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 177: 0.8952
# --- Round 178 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 178: 0.8752
# --- Round 179 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 179: 0.5483
# --- Round 180 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 180: 0.9066
# --- Round 181 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 181: 0.9425
# --- Round 182 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 182: 0.9287
# --- Round 183 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 183: 0.9227
# --- Round 184 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 184: 0.8941
# --- Round 185 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 185: 0.9295
# --- Round 186 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 186: 0.9193
# --- Round 187 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 187: 0.9270
# --- Round 188 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 188: 0.9379
# --- Round 189 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 189: 0.9413
# --- Round 190 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 190: 0.9308
# --- Round 191 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 191: 0.9320
# --- Round 192 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 192: 0.8911
# --- Round 193 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 193: 0.8788
# --- Round 194 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 194: 0.3180
# --- Round 195 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 195: 0.8890
# --- Round 196 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 196: 0.9348
# --- Round 197 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 197: 0.8547
# --- Round 198 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 198: 0.6201
# --- Round 199 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 199: 0.6389
# --- Round 200 ---
# Processing Cluster 1
# Processing Cluster 2
# Average Dice Score after Round 200: 0.8629
# Total communication cost: 7698.22 MB
# Total communication time: 28.52 seconds
# Total parameters exchanged: 1924548000

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedcluster.round_loss_values[i],
        'dice_scores': fedcluster.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedcluster.communication_cost if i == 0 else '',
        'communication_time': fedcluster.communication_time if i == 0 else '',
        'parameter_count': fedcluster.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedc_kd_r200_niid_plot.csv', index=False)

print("CSV file saved as 'fedc_kd_r200_niid_plot.csv'")
df
# Out:
# CSV file saved as 'fedc_kd_r200_niid_plot.csv'
#      round  round_losses dice_scores model_size communication_time  \
# 0        1      0.605714              478116800          14.470428
# 1        2      0.591351    0.033404
# 2        3      0.581811
# 3        4      0.567760    0.059243
# 4        5      0.555551
# ..     ...           ...         ...        ...                ...
# 195    196      0.200636    0.923943
# 196    197      0.167078
# 197    198      0.193291    0.927936
# 198    199      0.136929
# 199    200      0.208669    0.913733
#
#     parameter_count
# 0         119524000
# 1
# 2
# 3
# 4
# ..              ...
# 195
# 196
# 197
# 198
# 199
#
# [200 rows x 6 columns]

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedcluster_nkd.round_loss_values[i],
        'dice_scores': fedcluster_nkd.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedcluster_nkd.communication_cost if i == 0 else '',
        'communication_time': fedcluster_nkd.communication_time if i == 0 else '',
        'parameter_count': fedcluster_nkd.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedc_nkd_r200_niid_plot.csv', index=False)

print("CSV file saved as 'fedc_nkd_r200_niid_plot.csv'")
# Out:
# CSV file saved as 'fedc_nkd_r200_niid_plot.csv'

# %%
#IID KD
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

student_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(8, 16, 32, 64),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

# FedAvg configuration
num_clients = 4  # Total number of clients
#num_rounds = 2  # Number of communication rounds
client_fraction = 0.5  # Fraction of clients selected per round
local_epochs = 2  # Number of epochs each client trains locally
post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])


teacher_state_dict = torch.load(os.path.join(model_dir, "fedc_r200_iid.pth"))

teacher_model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
teacher_model.load_state_dict(teacher_state_dict['global_model_state'])

fedcluster_kd_iid = FedCluster(
    model=student_model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=client_fraction,
    local_epochs=local_epochs,
    batch_size=2,
    lr=1e-4,
    num_clusters=2,
    teacher_model=teacher_model,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedcluster_kd_iid.set_clients(train_client_datasets, val_client_datasets)

num_rounds = 200
fedcluster_kd_iid.run(num_rounds, post_pred, post_label, dice_metric)

torch.save({
    'round_losses': fedcluster_kd_iid.round_loss_values,
    'dice_scores': fedcluster_kd_iid.dice_metric_values,
    'model size': fedcluster_kd_iid.communication_cost,
    'communication time': fedcluster_kd_iid.communication_time,
    'parameter count': fedcluster_kd_iid.param_count,
    'global_model_state': fedcluster_kd_iid.global_model.state_dict()
}, 'fedc_kd_r200_iid.pth')

# %%
#IID Non-KD
fedcluster_nkd_iid = FedCluster(
    model=model,
    loss_function=loss_function,
    device=device,
    num_clients=num_clients,
    client_fraction=client_fraction,
    local_epochs=local_epochs,
    batch_size=2,
    lr=1e-4,
    num_clusters=2,
    teacher_model=None,  # Pass the teacher model
    alpha=0.7,                    # Weight for distillation loss
    temperature=3.0               # Temperature for softening logits
)

fedcluster_nkd_iid.set_clients(train_client_datasets, val_client_datasets)

num_rounds = 200     
fedcluster_nkd_iid.run(num_rounds, post_pred, post_label, dice_metric)

torch.save({
    'round_losses': fedcluster_nkd_iid.round_loss_values,
    'dice_scores': fedcluster_nkd_iid.dice_metric_values,
    'model size': fedcluster_nkd_iid.communication_cost,
    'communication time': fedcluster_nkd_iid.communication_time,
    'parameter count': fedcluster_nkd_iid.param_count,
    'global_model_state': fedcluster_nkd_iid.global_model.state_dict()
}, 'fedc_nkd_r200_iid.pth')

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedcluster_kd_iid.round_loss_values[i],
        'dice_scores': fedcluster_kd_iid.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedcluster_kd_iid.communication_cost if i == 0 else '',
        'communication_time': fedcluster_kd_iid.communication_time if i == 0 else '',
        'parameter_count': fedcluster_kd_iid.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedc_kd_r200_iid_plot.csv', index=False)

print("CSV file saved as 'fedc_kd_r200_iid_plot.csv'")
df
# Out:
# CSV file saved as 'fedc_kd_r200_iid_plot.csv'
#      round  round_losses dice_scores model_size communication_time  \
# 0        1      0.605714              478116800          12.765136
# 1        2      0.591350    0.033372
# 2        3      0.581809
# 3        4      0.567759    0.059096
# 4        5      0.555549
# ..     ...           ...         ...        ...                ...
# 195    196      0.201577    0.926182
# 196    197      0.166992
# 197    198      0.195321    0.928434
# 198    199      0.137545
# 199    200      0.208757    0.918539
#
#     parameter_count
# 0         119524000
# 1
# 2
# 3
# 4
# ..              ...
# 195
# 196
# 197
# 198
# 199
#
# [200 rows x 6 columns]

# %%
data = []
for i in range(200):
    round_data = {
        'round': i+1,
        'round_losses': fedcluster_nkd_iid.round_loss_values[i],
        'dice_scores': fedcluster_nkd_iid.dice_metric_values[i] if i % 2 != 0 else '',  # 'NA' for even rounds
        'model_size': fedcluster_nkd_iid.communication_cost if i == 0 else '',
        'communication_time': fedcluster_nkd_iid.communication_time if i == 0 else '',
        'parameter_count': fedcluster_nkd_iid.param_count if i == 0 else ''
    }
    data.append(round_data)

df = pd.DataFrame(data)
df.to_csv('fedc_nkd_r200_iid_plot.csv', index=False)

print("CSV file saved as 'fedc_nkd_r200_iid_plot.csv'")
df
